# %%
import os
import re
import pickle
import numpy as np
import pandas as pd
from dotenv import dotenv_values
from langchain import PromptTemplate, LLMChain, OpenAI
from langchain.chat_models import ChatOpenAI
from langchain.schema import SystemMessage, HumanMessage, AIMessage

# %%
# Load env file with API KEY using full path
config = dotenv_values('../.env')
os.environ['OPENAI_API_KEY'] = config["OPENAI_API_KEY"]
OPENAI_API_KEY = config["OPENAI_API_KEY"]

# %%
labels_to_text = {
    "I dont'know": "I dont'know",
    "datePublished": "date published",
    "isbn": "isbn",
    "numberOfPages": "number of pages",
    "worstRating": "worst rating",
    "priceCurrency": "price currency",
    "publisher": "publisher",
    "author": "author",
    "bookFormat": "book format",
    "inLanguage": "in language",
    "ratingValue": "rating value",
    "description": "description",
    "price": "price",
    "image": "image",
    "url": "url",
    "availability": "availability",
    "genre": "genre",
    "bestRating": "best rating",
    "itemCondition": "item condition",
    "review": "review",
    "startDate": "start date",
    "endDate": "end date",
    "location": "location",
    "validFrom": "valid from",
    "eventStatus": "event status",
    "eventAttendanceMode": "event attendance mode",
    "organizer": "organizer",
    "category": "category",
    "validThrough": "valid through",
    "telephone": "telephone",
    "duration": "duration",
    "email": "email",
    "streetAddress": "street address",
    "addressRegion": "region of address",
    "addressLocality": "locality of address",
    "priceRange": "price range",
    "postalCode": "postal code",
    "addressCountry": "address country",
    "faxNumber": "fax number",
    "dateCreated": "date created",
    "director": "director",
    "contentRating": "content rating",
    "actor": "actor",
    "inAlbum": "in album",
    "byArtist": "by artist",
    "jobTitle": "job title",
    "birthDate": "birth date",
    "gender": "gender",
    "nationality": "nationality",
    "weight": "weight",
    "releaseDate": "release date",
    "copyrightYear": "copyright year",
    "bookEdition": "book edition",
    "headline": "headline",
    "text": "text",
    "address": "address",
    "performer": "performer",
    "longitude": "longitude",
    "latitude": "latitude",
    "currenciesAccepted": "currencies accepted",
    "checkoutTime": "checkout time",
    "checkInTime": "check-in time",
    "amenityFeature": "amenity feature",
    "paymentAccepted": "payment accepted",
    "availableLanguage": "available language",
    "brand": "brand",
    "openingHours": "opening hours",
    "datePosted": "date posted",
    "employmentType": "employment type",
    "hiringOrganization": "hiring organization",
    "opens": "opens",
    "dayOfWeek": "day of week",
    "closes": "closes",
    "productionCompany": "production company",
    "countryOfOrigin": "country of origin",
    "numTracks": "number of tracks",
    "track": "track",
    "givenName": "given name",
    "familyName": "family name",
    "birthPlace": "birth place",
    "honorificSuffix": "honorific suffix",
    "alumniOf": "alumni of",
    "deathDate": "death date",
    "measurements": "measurements",
    "unitCode": "unit code",
    "productID": "product ID",
    "unitText": "unit text",
    "availableDeliveryMethod": "available delivery method",
    "model": "model",
    "manufacturer": "manufacturer",
    "color": "color",
    "gtin": "gtin",
    "material": "material",
    "servingSize": "serving size",
    "recipeInstructions": "recipe instructions",
    "recipeIngredient": "recipe ingredient",
    "cookTime": "cook time",
    "prepTime": "prep time",
    "totalTime": "total time",
    "nutrition": "nutrition",
    "recipeCategory": "recipe category",
    "recipeCuisine": "recipe cuisine",
    "cookingMethod": "cooking method",
    "suitableForDiet": "suitable for diet",
    "servesCuisine": "serves cuisine",
    "awayTeam": "away team",
    "homeTeam": "home team",
    "partOfSeries": "part of series",
    "episodeNumber": "episode number"
}

# %%
len(labels_to_text)
# Out:
# 109

# %%
text_to_label = {
    "I dont'know": "-",
    "date published": "datePublished",
    "isbn": "isbn",
    "number of pages": "numberOfPages",
    "worst rating": "worstRating",
    "price currency": "priceCurrency",
    "publisher": "publisher",
    "author": "author",
    "book format": "bookFormat",
    "in language": "inLanguage",
    "rating value": "ratingValue",
    "description": "description",
    "price": "priceRange",
    "image": "image",
    "url": "url",
    "availability": "availability",
    "genre": "genre",
    "best rating": "bestRating",
    "item condition": "itemCondition",
    "review": "review",
    "start date": "startDate",
    "end date": "endDate",
    "location": "location",
    "valid from": "validFrom",
    "event status": "eventStatus",
    "event attendance mode": "eventAttendanceMode",
    "organizer": "organizer",
    "category": "category",
    "valid through": "validThrough",
    "telephone": "telephone",
    "duration": "duration",
    "email": "email",
    "street address": "streetAddress",
    "region of address": "addressRegion",
    "locality of address": "addressLocality",
    "price range": "priceRange",
    "postal code": "postalCode",
    "address country": "addressCountry",
    "fax number": "faxNumber",
    "date created": "dateCreated",
    "director": "director",
    "content rating": "contentRating",
    "actor": "actor",
    "in album": "inAlbum",
    "by artist": "byArtist",
    "job title": "jobTitle",
    "birth date": "birthDate",
    "gender": "gender",
    "nationality": "nationality",
    "weight": "weight",
    "release date": "releaseDate",
    "copyright year": "copyrightYear",
    "book edition": "bookEdition",
    "headline": "headline",
    "text": "text",
    "address": "address",
    "performer": "performer",
    "longitude": "longitude",
    "latitude": "latitude",
    "currencies accepted": "currenciesAccepted",
    "checkout time": "checkoutTime",
    "check-in time": "checkInTime",
    "amenity feature": "amenityFeature",
    "payment accepted": "paymentAccepted",
    "available language": "availableLanguage",
    "brand": "brand",
    "opening hours": "openingHours",
    "date posted": "datePosted",
    "employment type": "employmentType",
    "hiring organization": "hiringOrganization",
    "opens": "opens",
    "day of week": "dayOfWeek",
    "closes": "closes",
    "production company": "productionCompany",
    "country of origin": "countryOfOrigin",
    "number of tracks": "numTracks",
    "track": "track",
    "given name": "givenName",
    "family name": "familyName",
    "birth place": "birthPlace",
    "honorific suffix": "honorificSuffix",
    "alumni of": "alumniOf",
    "death date": "deathDate",
    "measurements": "measurements",
    "unit code": "unitCode",
    "product ID": "productID",
    "unit text": "unitText",
    "available delivery method": "availableDeliveryMethod",
    "model": "model",
    "manufacturer": "manufacturer",
    "color": "color",
    "gtin": "gtin",
    "material": "material",
    "serving size": "servingSize",
    "recipe instructions": "recipeInstructions",
    "recipe ingredient": "recipeIngredient",
    "cook time": "cookTime",
    "prep time": "prepTime",
    "total time": "totalTime",
    "nutrition": "nutrition",
    "recipe category": "recipeCategory",
    "recipe cuisine": "recipeCuisine",
    "cooking method": "cookingMethod",
    "suitable for diet": "suitableForDiet",
    "serves cuisine": "servesCuisine",
    "away team": "awayTeam",
    "home team": "homeTeam",
    "part of series": "partOfSeries",
    "episode number": "episodeNumber"
}

# %% [markdown]
# ## Load test (and training) set

# %%
with open('sotabv2-cpa-train-column.pkl', "rb") as f:
    train = pickle.load(f)
with open('sotabv2-cpa-test-column.pkl', "rb") as f:
    test = pickle.load(f) 
examples = [example[2] for example in test ]      #changed
labels = [example[3] for example in test ]

train_examples = [ example[2] for example in train ]
train_labels = [ labels_to_text[example[3]] for example in train ]

# %%
print(examples[1])   #examples to use for prompts
# Out:
# Column 1: Medusa’s Master Angela's Ashes A Baby for Mommy A Handbook for Morning Time The Intentional Brain
#  Column 2: English English English English

# %%
print(test[0][1])
# Out:
# 4

# %%
#  Per me gjet tabelat me te gjitha labelsat, krahaso cdo tabel duke marr len() e unique() values te kolones target me len(te keys nga labels_to_text dict ), 
#nqs len esht i = ruaj emrat ne nje list S

# %%
dfSp = pd.read_json('Test/Book_9facts.co.uk_September2020_CPA.json.gz', compression='gzip', lines=True)
dfSp
# Out:
#                                               0   \
# 0                                Medusa’s Master
# 1                                 Angela's Ashes
# 2                               A Baby for Mommy
# 3                    A Handbook for Morning Time
# 4                          The Intentional Brain
# ..                                           ...
# 314                                     Hellfire
# 315  Her Christmas Guardian (Mission: Rescue #2)
# 316                    A Midsummer Night's Dream
# 317                                   Save Rafe!
# 318                           The Paperclip Test
#
#                                                     1                    2   \
# 0    I read this just after finishing Cindy Dees Cl...           Cindy Dees
# 1    What, did NO one find this book funny except m...        Frank McCourt
# 2    FORBIDDEN LOVE Being stranded with a beautiful...           Sara Orwig
# 3    This compact handbook will provide insights, t...        Cindy Rollins
# 4    Neuropsychiatry has a distinguished history, y...   Michael R. Trimble
# ..                                                 ...                  ...
# 314  Jack Tanner s war takes him to the treacherous...        James Holland
# 315  [TO SAVE HER DAUGHTER Former army ranger Boone...        Shirlee McCoy
# 316  The Arden Shakespeare is the established editi...  William Shakespeare
# 317  [James Patterson s hilarious story of persever...      James Patterson
# 318  [Learn something new about yourself todayWhat ...          Mario Gmurr
#
#                  3                                                  4   \
# 0         Paperback  http://9facts.co.uk/wp-content/upload/2017/7a7...
# 1         Paperback                                               None
# 2             ebook  http://9facts.co.uk/wp-content/upload/2017/7a7...
# 3         Paperback  http://9facts.co.uk/wp-content/upload/2017/7a7...
# 4         Hardcover                                               None
# ..              ...                                                ...
# 314       Hardcover                                               None
# 315       Paperback                                               None
# 316       Paperback  http://9facts.co.uk/wp-content/upload/2017/7a7...
# 317  Kindle Edition                                               None
# 318       Hardcover                                               None
#
#             5           6                                                  7   \
# 0    218 pages  0373276400  Review Medusa’s Master Rar, characters Medusa’...
# 1    452 pages  0007205236  characters Angela's Ashes epub|lit|mob, summar...
# 2    138 pages  1459271483  Review A Baby for Mommy Rar, characters A Baby...
# 3    112 pages  0986325759  Library A Handbook for Morning Time Audible Au...
# 4    328 pages  1421419491  Review The Intentional Brain Rar, summary pdf ...
# ..         ...         ...                                                ...
# 314  352 pages  0593058402  shares Hellfire Ebook Kindle, explained Hellfi...
# 315  224 pages  0373446365  free download Her Christmas Guardian (Mission:...
# 316  312 pages  1903436605  download A Midsummer Night's Dream books, char...
# 317  280 pages        None  free trailer Save Rafe! Text File, explained S...
# 318  208 pages  1910931004  free quotes The Paperclip Test Epub File, summ...
#
#                       8    9        10     11
# 0             Cindy Dees  NaN  English    NaN
# 1          Frank McCourt  3.3  English  411.0
# 2             Sara Orwig  NaN  English    NaN
# 3          Cindy Rollins  NaN  English    NaN
# 4     Michael R. Trimble  3.3     None  415.0
# ..                   ...  ...      ...    ...
# 314        James Holland  2.1  English  121.0
# 315        Shirlee McCoy  4.5     None  943.0
# 316  William Shakespeare  NaN  English    NaN
# 317      James Patterson  4.5  English   11.0
# 318          Mario Gmurr  3.3     None  427.0
#
# [319 rows x 12 columns]

# %% [markdown]
# ## Choose setup: zero-shot, one-shot or five-shot

# %% [markdown]
# e.g. CPA PROMPTS

# %%
""" df = pd.read_csv("sotab_v2_cpa_training_set.csv")
list_of_labels = df['label'].unique()
print(list_of_labels)
len(list_of_labels)  """

# %%
import json
import gzip

df = pd.read_csv("sotab_v2_cpa_training_set.csv")
table_names = df['table_name'].tolist()

list_of_labels = df['label'].unique()


length_threshold = 10


close_tables = []


for table_name in table_names:

    file_path = rf"Train\{table_name}"
    
    with gzip.open(file_path, 'rt', encoding='utf-8') as f:
       
        table = pd.read_json(f, lines=True)

  
    label_column = table['label']

    
    if abs(len(label_column.unique()) - len(list_of_labels)) <= length_threshold:
        close_tables.append(table_name)

# Print the list of tables that are close to the length of list_of_labels
print("Tables with length close to list_of_labels:", close_tables)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\ProgramData\Anaconda3\envs\myenv\lib\site-packages\pandas\core\indexes\base.py:3653, in Index.get_loc(self, key)
#    3652 try:
# -> 3653     return self._engine.get_loc(casted_key)
#    3654 except KeyError as err:
#
# File c:\ProgramData\Anaconda3\envs\myenv\lib\site-packages\pandas\_libs\index.pyx:147, in pandas._libs.index.IndexEngine.get_loc()
#
# File c:\ProgramData\Anaconda3\envs\myenv\lib\site-packages\pandas\_libs\index.pyx:155, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\index_class_helper.pxi:70, in pandas._libs.index.Int64Engine._check_type()
#
# KeyError: 'label'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# c:\Users\Administrator\TabAnnGPT\SOTAB CPA\Chat-column-experiments.ipynb Cell 15 line 2
#      <a href='vscode-notebook-cell:/c%3A/Users/Administrator/TabAnnGPT/SOTAB%20CPA/Chat-column-experiments.ipynb#X21sZmlsZQ%3D%3D?line=19'>20</a> with gzip.open(file_path, 'rt', encoding='utf-8') as f:
#      <a href='vscode-notebook-cell:/c%3A/Users/Administrator/TabAnnGPT/SOTAB%20CPA/Chat-column-experiments.ipynb#X21sZmlsZQ%3D%3D?line=21'>22</a>     table = pd.read_json(f, lines=True)
# ---> <a href='vscode-notebook-cell:/c%3A/Users/Administrator/TabAnnGPT/SOTAB%20CPA/Chat-column-experiments.ipynb#X21sZmlsZQ%3D%3D?line=24'>25</a> label_column = table['label']
#      <a href='vscode-notebook-cell:/c%3A/Users/Administrator/TabAnnGPT/SOTAB%20CPA/Chat-column-experiments.ipynb#X21sZmlsZQ%3D%3D?line=27'>28</a> if abs(len(label_column.unique()) - len(list_of_labels)) <= length_threshold:
#      <a href='vscode-notebook-cell:/c%3A/Users/Administrator/TabAnnGPT/SOTAB%20CPA/Chat-column-experiments.ipynb#X21sZmlsZQ%3D%3D?line=28'>29</a>     close_tables.append(table_name)
#
# File c:\ProgramData\Anaconda3\envs\myenv\lib\site-packages\pandas\core\frame.py:3761, in DataFrame.__getitem__(self, key)
#    3759 if self.columns.nlevels > 1:
#    3760     return self._getitem_multilevel(key)
# -> 3761 indexer = self.columns.get_loc(key)
#    3762 if is_integer(indexer):
#    3763     indexer = [indexer]
#
# File c:\ProgramData\Anaconda3\envs\myenv\lib\site-packages\pandas\core\indexes\base.py:3655, in Index.get_loc(self, key)
#    3653     return self._engine.get_loc(casted_key)
#    3654 except KeyError as err:
# -> 3655     raise KeyError(key) from err
#    3656 except TypeError:
#    3657     # If we have a listlike key, _check_indexing_error will raise
#    3658     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3659     #  the TypeError.
#    3660     self._check_indexing_error(key)
#
# KeyError: 'label'

# %%
labels_joined = ", ".join(list(set(labels)))
labels_joined
# Out:
# 'byArtist, itemCondition, actor, inLanguage, organizer, honorificSuffix, postalCode, givenName, gtin, director, address, totalTime, review, description, homeTeam, manufacturer, productionCompany, numberOfPages, addressRegion, url, servesCuisine, priceCurrency, location, copyrightYear, inAlbum, isbn, checkInTime, releaseDate, addressLocality, numTracks, recipeIngredient, publisher, checkoutTime, category, countryOfOrigin, color, alumniOf, opens, addressCountry, amenityFeature, availability, awayTeam, suitableForDiet, prepTime, validFrom, deathDate, model, genre, unitCode, hiringOrganization, cookingMethod, openingHours, paymentAccepted, latitude, productID, datePosted, unitText, longitude, dayOfWeek, dateCreated, datePublished, gender, closes, bookFormat, birthDate, streetAddress, endDate, nationality, email, availableDeliveryMethod, availableLanguage, currenciesAccepted, eventStatus, contentRating, servingSize, birthPlace, weight, bestRating, recipeCuisine, measurements, price, nutrition, image, brand, eventAttendanceMode, worstRating, priceRange, recipeCategory, validThrough, author, telephone, employmentType, duration, material, startDate, partOfSeries, faxNumber, bookEdition, headline, episodeNumber, jobTitle, cookTime, ratingValue, text, performer, recipeInstructions, familyName, track'

# %%
f"Your task is to classify the relation of the two given columns with only one of the following types that are separated with comma: {labels_joined}"
# Out:
# 'Your task is to classify the relation of the two given columns with only one of the following types that are separated with comma: byArtist, itemCondition, actor, inLanguage, organizer, honorificSuffix, postalCode, givenName, gtin, director, address, totalTime, review, description, homeTeam, manufacturer, productionCompany, numberOfPages, addressRegion, url, servesCuisine, priceCurrency, location, copyrightYear, inAlbum, isbn, checkInTime, releaseDate, addressLocality, numTracks, recipeIngredient, publisher, checkoutTime, category, countryOfOrigin, color, alumniOf, opens, addressCountry, amenityFeature, availability, awayTeam, suitableForDiet, prepTime, validFrom, deathDate, model, genre, unitCode, hiringOrganization, cookingMethod, openingHours, paymentAccepted, latitude, productID, datePosted, unitText, longitude, dayOfWeek, dateCreated, datePublished, gender, closes, bookFormat, birthDate, streetAddress, endDate, nationality, email, availableDeliveryMethod, availableLanguage, currenciesAccepted, eventStatus, contentRating, servingSize, birthPlace, weight, bestRating, recipeCuisine, measurements, price, nutrition, image, brand, eventAttendanceMode, worstRating, priceRange, recipeCategory, validThrough, author, telephone, employmentType, duration, material, startDate, partOfSeries, faxNumber, bookEdition, headline, episodeNumber, jobTitle, cookTime, ratingValue, text, performer, recipeInstructions, familyName, track'

# %%
    
messages = []
    
messages.append(SystemMessage(content="Your task is to classify the relation of the two given columns with only one of the following types that are separated with comma: {}"))    
messages.append(SystemMessage(content="Your instructions are: 1. Look at the two columns and the types given to you. 2. Examine the values of these columns. 3. Select a type that best represents the relation between the two columns. 4. Return only the column type,no explanation needed."))
    
messages.append(HumanMessage(content="Classify the type of relation between these columns: {} "))

sample_prompt=messages

# %% [markdown]
# ZERO SHOT

# %%
#Zero-shot column + instructions + roles
preds = []

for example in examples[0:50]:
    
    messages = []
    
    #Add system message
    messages.append(SystemMessage(content=f"Your task is to classify the relation of the two given columns with only one of the following types that are separated with comma: {labels_joined}"))    
    messages.append(SystemMessage(content="Your instructions are: 1. Look at the two columns and the types given to you. 2. Examine the values of these columns. 3. Select a type that best represents the relation between the two columns. 4. Return only the column type,no explanation needed."))
    
    messages.append(HumanMessage(content=f"Classify the type of relation between these columns: {example}"))
    res = chat(messages)
    preds.append(res.content)

# %%
messages
# Out:
# [SystemMessage(content='Your task is to classify the relation of the two given columns with only one of the following types that are separated with comma: {}'),
#  SystemMessage(content='Your instructions are: 1. Look at the two columns and the types given to you. 2. Examine the values of these columns. 3. Select a type that best represents the relation between the two columns. 4. Return only the column type,no explanation needed.'),
#  HumanMessage(content='Classify the type of relation between these columns: {} ')]

# %%
preds
# Out:
# ['inAlbum',
#  'inLanguage',
#  'bookFormat',
#  'numberOfPages',
#  'gtin',
#  'publisher',
#  'inAlbum',
#  'numTracks',
#  'itemCondition',
#  'partOfSeries']

# %% [markdown]
# ONE SHOT

# %%
""" import random
#One-shot column + instructions + roles
preds = []
for example in examples:
    messages = []
    
    #Add system message
    messages.append(SystemMessage(content="Your task is to classify a given column with only one of the following types that are separated with comma: description of event, description of restaurant, locality of address, postal code, region of address, country, price range, telephone, date, name of restaurant, payment accepted, day of week, review, organization, date and time, coordinate, name of event, event attendance mode, event status, currency, time, description of hotel, name of hotel, location feature, rating, fax number, email, photograph, name of music recording, music artist, name of album, duration."))    
    messages.append(SystemMessage(content="Your instructions are: 1. Look at the column and the types given to you. 2. Examine the values of the column. 3. Select a type that best represents the meaning of the column. 4. Answer with the selected type."))

    #One random example from the training set
    index = random.randint(0, len(train_examples)-1)
    messages.append(HumanMessage(content=f"Classify this column: {train_examples[index]}"))
    messages.append(AIMessage(content=f"{train_labels[index]}"))
    
    messages.append(HumanMessage(content=f"Classify this column: {example}"))
    res = chat(messages)
    preds.append(res.content) """

# %% [markdown]
# FIVE SHOT

# %%
""" import random
#Five-shot column + instructions + roles
preds = []
for example in examples:
    messages = []
    
    #Add system message
    messages.append(SystemMessage(content="Your task is to classify a given column with only one of the following types that are separated with comma: description of event, description of restaurant, locality of address, postal code, region of address, country, price range, telephone, date, name of restaurant, payment accepted, day of week, review, organization, date and time, coordinate, name of event, event attendance mode, event status, currency, time, description of hotel, name of hotel, location feature, rating, fax number, email, photograph, name of music recording, music artist, name of album, duration."))    
    messages.append(SystemMessage(content="Your instructions are: 1. Look at the column and the types given to you. 2. Examine the values of the column. 3. Select a type that best represents the meaning of the column. 4. Answer with the selected type."))
    
    #Add 5 random examples
    for i in range(0,5):
        index = random.randint(0, len(train_examples)-1)
        messages.append(HumanMessage(content=f"Classify this column: {train_examples[index]}"))
        messages.append(AIMessage(content=f"{train_labels[index]}"))
    
    messages.append(HumanMessage(content=f"Classify this column: {example}"))
    res = chat(messages)
    preds.append(res.content) """

# %%
preds[:10]
# Out:
# ['category',
#  'The type that best represents the relation between the two columns is "inLanguage".',
#  'The relation between the two columns is "itemCondition".',
#  'numberOfPages',
#  'The relation between the two columns seems to be related to the ISBN (International Standard Book Number) of the books. Therefore, the type that best represents this relation is "gtin".',
#  'publisher',
#  'category',
#  'The relation between the two columns seems to be "numTracks" as the values in column 2 appear to be the number of tracks or chapters in each of the items listed in column 1.',
#  'The type that best represents the relation between these two columns is `inStock`.',
#  'The relation between the two columns is not clear and there is no apparent connection between them. Therefore, the answer is "no relation".']

# %%
""" import os

directory = 'Predictions/gpt-3.5-turbo-0301/'
os.makedirs(directory, exist_ok=True) """

# %%
#Save predictions in a file:
file_name=f'Predictions/{model_name}/s1-column-zero-shot.pkl'   #changed
f = open(file_name,'wb')
pickle.dump(preds,f)
f.close()

# %% [markdown]
# ## Evaluation

# %%
predictions = []
for i, pred in enumerate(preds):
    from_sent = re.findall('"([^"]*)"',pred)
    if len(from_sent) == 0:
        if ":" in pred:
            pred = pred.split(':')[1]
        if "." in pred:
            pred = pred.split('.')[0]
        pred = pred.strip().lower()
        
        if pred in text_to_label:
            predictions.append(text_to_label[pred])
        else:
            if any(label in pred for label in text_to_label):
                for label in text_to_label:
                    if label in pred:
                        predictions.append(text_to_label[label])
                        break
            else:
                print(f"For test example {i} out of label space prediction: {pred}")
                predictions.append('-')

    # If predictions is between quotation marks ""
    else:
        if from_sent[0].lower() in text_to_label:
            predictions.append(text_to_label[from_sent[0].lower()])
        else:
            print(f"For test example {i} out of label space prediction: {pred}")
            predictions.append('-')
# Out:
# For test example 1 out of label space prediction: The type that best represents the relation between the two columns is "inLanguage".
# For test example 2 out of label space prediction: The relation between the two columns is "itemCondition".
# For test example 3 out of label space prediction: numberofpages
# For test example 7 out of label space prediction: The relation between the two columns seems to be "numTracks" as the values in column 2 appear to be the number of tracks or chapters in each of the items listed in column 1.
# For test example 8 out of label space prediction: the type that best represents the relation between these two columns is `instock`
# For test example 9 out of label space prediction: The relation between the two columns is not clear and there is no apparent connection between them. Therefore, the answer is "no relation".
# For test example 11 out of label space prediction: it is not possible to classify the relation between the two columns as they do not seem to have any meaningful connection
# For test example 13 out of label space prediction: The relation between the two columns seems to be "bookTitle".
# For test example 14 out of label space prediction: it is not clear what the relation is between the two columns
# For test example 15 out of label space prediction: the type of relation between the two columns is itemcondition
# For test example 18 out of label space prediction: itemcondition
# For test example 25 out of label space prediction: The type that best represents the relation between the two columns is "eventDate".
# For test example 27 out of label space prediction: i'm sorry, but i cannot find any relation between the two columns
# For test example 29 out of label space prediction: The type that best represents the relation between the two columns is "eventDate".
# For test example 30 out of label space prediction: The type that best represents the relation between the two columns is "EventScheduled".
# For test example 31 out of label space prediction: The type that best represents the relation between the two columns is "event".
# For test example 32 out of label space prediction: The type that best represents the relation between the two columns is "eventDate".
# For test example 35 out of label space prediction: Based on the given values in both columns, it seems that there is no clear relation between them. Therefore, I would classify the type as "N/A" (not applicable).
# For test example 37 out of label space prediction: It seems that there is no clear relation between the two columns. The values in column 2 are all "inStock" which is related to availability of a product, while the values in column 1 are names of events. Therefore, I cannot classify the relation between these two columns with any of the given types.
# For test example 38 out of label space prediction: The type that best represents the relation between the two columns is "eventDate".
# For test example 40 out of label space prediction: there doesn't seem to be any clear relation between the two columns
# For test example 41 out of label space prediction: the relation between the two columns is not clear
# For test example 42 out of label space prediction: The relation between the two columns is not clear. It seems like Column 1 contains event names or titles, while Column 2 contains the word "primary" repeated multiple times. Without more context or information, it is not possible to classify the relation between these two columns with any of the given types.
# For test example 43 out of label space prediction: The type of relation between these columns is "eventDate".
# For test example 45 out of label space prediction: I'm sorry, but based on the given information, I cannot find a clear relation between the two columns. Column 1 seems to contain event names or titles, while Column 2 contains the status of being "InStock". Please provide more context or information so I can assist you better.
# For test example 46 out of label space prediction: The type of relation between these columns is "eventDate".
# For test example 47 out of label space prediction: The type that best represents the relation between the two columns is "EventScheduled".
# For test example 48 out of label space prediction: the type that best represents the relation between the two columns is eventattendancemode
# For test example 49 out of label space prediction: The relation between the two columns seems to be related to the schedule or timing of the events mentioned in Column 1. Therefore, the type that best represents this relation is "schedule" or "timing".
# For test example 50 out of label space prediction: the type that best represents the relation between the two columns is `eventattendancemode`
# For test example 53 out of label space prediction: the relation between the two columns seems to be contact information for events and conferences
# For test example 57 out of label space prediction: it seems that both columns are not related to each other
# For test example 58 out of label space prediction: i'm sorry, but based on the given columns, i cannot find any relation between them that can be classified with the types provided
# For test example 59 out of label space prediction: The type that best represents the relation between the two columns is "eventDate".
# For test example 60 out of label space prediction: The relation between the two columns is "event".
# For test example 62 out of label space prediction: The type that best represents the relation between the two columns is "County Council Meeting".
# For test example 64 out of label space prediction: The relation between the two columns seems to be "committee member" or "committee participant".
# For test example 65 out of label space prediction: It seems that the values in Column 2 are phone numbers, which are not related to the values in Column 1. Therefore, the type of relation between these columns is "unrelated".
# For test example 66 out of label space prediction: The type that best represents the relation between the two columns is "startDate".
# For test example 67 out of label space prediction: the type that best represents the relation between the two columns is eventattendancemode
# For test example 69 out of label space prediction: The type that best represents the relation between the two columns is "EventScheduled".
# For test example 70 out of label space prediction: the relation between the two columns is `byartist`
# For test example 74 out of label space prediction: the type that best represents the relation between the two columns is `postalcode`
# For test example 77 out of label space prediction: The relation between the two columns seems to be "addressRegion".
# For test example 78 out of label space prediction: The relation between the two columns seems to be "addressLocality" as all the values in column 2 are the locality/city names where the entities in column 1 are located.
# For test example 79 out of label space prediction: the type that best represents the relation between the two columns is `postalcode`
# For test example 81 out of label space prediction: based on the given values in the columns, the relation between them seems to be related to contact information
# For test example 83 out of label space prediction: based on the given columns, it seems that there is no clear relation between them
# For test example 84 out of label space prediction: The relation between the two columns seems to be the release date of the movies mentioned in Column 1. Therefore, the type that best represents this relation is "releaseDate".
# For test example 86 out of label space prediction: the relation between the two columns seems to be the `totaltime` of the movies listed in column 1
# For test example 87 out of label space prediction: the relation between the two columns is byartist, as the values in column 2 are the movie posters of the movies listed in column 1, and the artist responsible for creating these posters is the same
# For test example 89 out of label space prediction: The relation between the two columns seems to be "byArtist" as the second column contains the names of actors who might have acted in the movies or documentaries mentioned in the first column.
# For test example 93 out of label space prediction: the relation between the two columns seems to be the itemcondition, as the values in column 2 represent the rating or classification of the movies in column 1
# For test example 98 out of label space prediction: the relation between the two columns is itemcondition, as the second column describes the rating of the movies in the first column
# For test example 99 out of label space prediction: The relation between the two columns is "byArtist" as all the songs in Column 1 are performed by the same artist, Bryan Hayes, which is mentioned in Column 2.
# For test example 100 out of label space prediction: The relation between the two columns is "year" as it represents the year in which each song was performed live. Therefore, the type is "datePublished".
# For test example 102 out of label space prediction: The type that best represents the relation between the two columns is "title".
# For test example 104 out of label space prediction: The type that best represents the relation between the two columns is "playerPosition".
# For test example 105 out of label space prediction: The type that best represents the relation between the two columns is "homeTeam".
# For test example 106 out of label space prediction: the relation between the two columns is byartist, as all the values in column 1 are names of chefs and all the values in column 2 describe their roles in the culinary industry
# For test example 110 out of label space prediction: The type that best represents the relation between the two columns is "byArtist".
# For test example 112 out of label space prediction: the relation between the two columns seems to be irrelevant or unclear
# For test example 113 out of label space prediction: The relation between the two columns seems to be related to professions or services. Therefore, the appropriate type for this relation is "hiringOrganization".
# For test example 116 out of label space prediction: The relation between Column 1 and Column 2 seems to be related to the birth dates of the individuals in Column 1. Therefore, the type that best represents this relation is "birthDate".
# For test example 118 out of label space prediction: The relation between the two columns seems to be related to the positions played in a football team. Therefore, the type that best represents this relation is "position" or "playerPosition".
# For test example 122 out of label space prediction: the relation between column 1 and column 2 seems to be byartist, as the values in column 2 represent the birth years of the artists listed in column 1
# For test example 123 out of label space prediction: The relation between the two columns is "byArtist" as both columns contain names of individuals and the second column describes their profession or job title.
# For test example 124 out of label space prediction: The relation between the two columns seems to be "byArtist", as the values in column 1 appear to be names of artists, and the values in column 2 could be their contact phone numbers.
# For test example 125 out of label space prediction: the type that best represents the relation between the two columns is givenname
# For test example 126 out of label space prediction: the relation between the two columns is not clear
# For test example 127 out of label space prediction: based on the values of the two columns, it seems that there is no clear relation between them that can be classified using the given types
# For test example 128 out of label space prediction: there doesn't seem to be any clear relation between the two columns
# For test example 130 out of label space prediction: itemcondition
# For test example 132 out of label space prediction: I'm sorry, but I cannot find any clear relation between the two columns. The first column seems to contain a list of fitness equipment and their descriptions, while the second column contains only the number "1.0" repeated four times. Could you please provide more context or clarify the task?
# For test example 133 out of label space prediction: The type that best represents the relation between the two columns is "productType".
# For test example 134 out of label space prediction: The relation between Column 1 and Column 2 is "MTG Booster Packs".
# For test example 136 out of label space prediction: The type of relation between the two columns is "product".
# For test example 137 out of label space prediction: the relation between the two columns is byproduct
# For test example 138 out of label space prediction: The relation between the two columns seems to be related to weight capacity or maximum weight that can be handled by the equipment listed in column 1. Therefore, the type that best represents this relation is "weight capacity" or "maximum weight".
# For test example 141 out of label space prediction: Based on the values in the two columns, the type that best represents the relation between them is "productReview".
# For test example 149 out of label space prediction: it is not clear what the relation is between the two columns based on the given information
# For test example 152 out of label space prediction: itemcondition
# For test example 153 out of label space prediction: itemcondition
# For test example 154 out of label space prediction: the given columns do not have any clear relation to any of the types provided
# For test example 155 out of label space prediction: The relation between the two columns is related to the publication date of the books in Column 1. Therefore, the type that best represents this relation is "releaseDate".
# For test example 156 out of label space prediction: The relation between the two columns is "byArtist" as the first column lists the names of the books written by the author David Baldacci, which is mentioned in the second column.
# For test example 163 out of label space prediction: The relation between the two columns seems to be the publication year of the books in Column 1. Therefore, the type that best represents this relation is "publicationYear".
# For test example 165 out of label space prediction: The relation between the two columns seems to be "byAuthor" as the first column contains book titles and the second column contains author names.
# For test example 166 out of label space prediction: The relation between the two columns seems to be unrelated. Therefore, the type is "N/A" (not applicable).
# For test example 167 out of label space prediction: The relation between the two columns seems to be "numberOfPages".
# For test example 168 out of label space prediction: The relation between the two columns is "itemCondition".
# For test example 169 out of label space prediction: the relation between the two columns is bydate
# For test example 175 out of label space prediction: The relation between the two columns seems to be related to the duration or length of something. Therefore, the type that best represents this relation is "totalTime".
# For test example 176 out of label space prediction: The type of relation between the two columns is "inAlbum".
# For test example 178 out of label space prediction: itemcondition
# For test example 179 out of label space prediction: itemcondition
# For test example 180 out of label space prediction: The relation between the two columns is "bookEdition".
# For test example 185 out of label space prediction: The relation between the two columns seems to be related to time. Therefore, the type that best represents this relation is "dateCreated".
# For test example 187 out of label space prediction: the relation between the two columns is not clear as there is no apparent connection between the values in column 1 and column 2
# For test example 189 out of label space prediction: It seems that the second column contains a name, "Yehudit", which is repeated for all the rows. Therefore, the relation between the two columns is byPerson, specifically the person who made or prepared the dishes listed in the first column is Yehudit.
# For test example 190 out of label space prediction: it is not possible to determine the relation between the two columns as they are completely unrelated to each other
# For test example 193 out of label space prediction: recipeinstructions
# For test example 194 out of label space prediction: The type that best represents the relation between the two columns is "event".
# For test example 196 out of label space prediction: the type that best represents the relation between the two columns is `eventattendancemode`
# For test example 197 out of label space prediction: The type that best represents the relation between the two columns is "event".
# For test example 200 out of label space prediction: the type that best represents the relation between the two columns is `eventattendancemode`
# For test example 204 out of label space prediction: The type that best represents the relation between these two columns is "EventScheduled".
# For test example 205 out of label space prediction: The type that best represents the relation between the two columns is "eventAttendanceMode".
# For test example 206 out of label space prediction: Based on the given columns, it seems that there is no clear relation between them. Therefore, I would classify the relation as "N/A" or "None".
# For test example 207 out of label space prediction: it seems that there is no clear relation between the values in column 1 and column 2
# For test example 208 out of label space prediction: I'm sorry, but it's not clear to me what the relation is between the two columns. The first column seems to contain two different types of training, while the second column contains the word "inStock" repeated four times. Could you please provide more context or information about the columns?
# For test example 209 out of label space prediction: The relation between Column 1 and Column 2 seems to be related to an event or conference. Therefore, the type that best represents this relation is "eventAttendanceMode".
# For test example 210 out of label space prediction: The relation between the two columns seems to be unrelated. Therefore, the answer is "unrelated".
# For test example 211 out of label space prediction: the relation between the two columns is not clear
# For test example 212 out of label space prediction: i'm sorry, but based on the given columns and types, i cannot find a suitable type that represents the relation between them
# For test example 213 out of label space prediction: the type that best represents the relation between these two columns is `event`
# For test example 214 out of label space prediction: The type that best represents the relation between these two columns is "eventAttendanceMode".
# For test example 215 out of label space prediction: the type that best represents the relation between the two columns is `eventattendancemode`
# For test example 216 out of label space prediction: the type that best represents the relation between the two columns is `eventscheduled`
# For test example 217 out of label space prediction: The type that best represents the relation between the two columns is "eventAttendanceMode".
# For test example 218 out of label space prediction: The type that best represents the relation between the two columns is "eventAttendanceMode".
# For test example 219 out of label space prediction: The relation between Column 1 and Column 2 seems to be related to an event or a performance. Therefore, the appropriate type for this relation is "event".
# For test example 220 out of label space prediction: the type of relation between these columns is `inlanguage`
# For test example 221 out of label space prediction: The type that best represents the relation between these columns is "eventDate".
# For test example 222 out of label space prediction: The type of relation between these columns is "eventDate".
# For test example 226 out of label space prediction: The type of relation between the two columns is "event".
# For test example 231 out of label space prediction: The type of relation between the two columns is "amenityFeature".
# For test example 233 out of label space prediction: The type that best represents the relation between the two columns is "hotelName".
# For test example 235 out of label space prediction: The type that best represents the relation between the two columns is "hotel" as all the values in column 1 are the names of a hotel and the values in column 2 are likely ratings for that hotel.
# For test example 236 out of label space prediction: The relation between the two columns seems to be "numberOfPages". However, it is important to note that this classification is based on the assumption that the values in Column 1 are actually referring to a hotel name and not a book title or something else entirely. If the assumption is incorrect, a different type may be more appropriate.
# For test example 237 out of label space prediction: the type that best represents the relation between the two columns is `inlanguage`, as the values in column 2 represent the languages in which the hotel name in column 1 is written
# For test example 238 out of label space prediction: The relation between the two columns is "amenityFeature".
# For test example 241 out of label space prediction: The type that best represents the relation between the two columns is "numberOfPages".
# For test example 242 out of label space prediction: The relation between the two columns seems to be "ratingValue".
# For test example 245 out of label space prediction: the type that best represents the relation between these two columns is `checkintime`
# For test example 246 out of label space prediction: the relation between the two columns is `checkintime`
# For test example 247 out of label space prediction: the type that best represents the relation between the two columns is `inlanguage`
# For test example 249 out of label space prediction: The relation between the two columns seems to be the geographical location of the given places. Therefore, the type that best represents this relation is "latitude, longitude".
# For test example 251 out of label space prediction: The relation between the two columns seems to be the "ratingValue" of the accommodations listed in column 1. Therefore, the type is "ratingValue".
# For test example 252 out of label space prediction: The relation between the two columns seems to be the "numberOfRooms" as all the values in column 2 are "1.0" which could represent the number of rooms in each of the properties listed in column 1. Therefore, the type of relation between these columns is "numberOfRooms".
# For test example 253 out of label space prediction: The relation between the two columns is "ratingValue".
# For test example 259 out of label space prediction: The relation between the values in Column 1 and Column 2 seems to be related to the geographical location of the hotels. Therefore, the appropriate type for this relation is "latitude, longitude"
# For test example 260 out of label space prediction: The type that best represents the relation between the two columns is "itemCondition".
# For test example 261 out of label space prediction: The relation between the two columns seems to be the amenities and services offered by each hotel. Therefore, the appropriate type for this relation is "amenityFeature".
# For test example 264 out of label space prediction: The relation between the two columns seems to be the "ratingValue" of the hotels. Therefore, the type is "ratingValue".
# For test example 265 out of label space prediction: The type that best represents the relation between the two columns is "amenityFeature".
# For test example 268 out of label space prediction: The relation between the two columns is "ratingValue".
# For test example 269 out of label space prediction: The type that best represents the relation between the two columns is "numberOfPages".
# For test example 270 out of label space prediction: the type that best represents the relation between the two columns is `inlanguage`
# For test example 271 out of label space prediction: the type that best represents the relation between these two columns is `checkintime`
# For test example 272 out of label space prediction: the type that best represents the relation between these two columns is `checkintime`
# For test example 273 out of label space prediction: The type that best represents the relation between these two columns is "inLanguage".
# For test example 275 out of label space prediction: the type that best represents the relation between the two columns is `postalcode`
# For test example 276 out of label space prediction: The type of relation between the two columns is "amenityFeature".
# For test example 279 out of label space prediction: itemcondition
# For test example 280 out of label space prediction: itemcondition
# For test example 281 out of label space prediction: The relation between the two columns is "inLanguage".
# For test example 282 out of label space prediction: The type that best represents the relation between the two columns is "checkInTime".
# For test example 283 out of label space prediction: The relation between the two columns is "inLanguage".
# For test example 285 out of label space prediction: the type that best represents the relation between the two columns is `checkintime`
# For test example 286 out of label space prediction: The type that best represents the relation between the two columns is "amenityFeature".
# For test example 287 out of label space prediction: The relation between the two columns seems to be the check-in time of the hotels listed in column 1. Therefore, the type that best represents this relation is "checkInTime".
# For test example 288 out of label space prediction: The relation between the two columns seems to be "priceRange".
# For test example 290 out of label space prediction: the type of relation between these columns is openinghours
# For test example 291 out of label space prediction: The relation between the two columns seems to be "byArtist" as all the values in column 1 seem to be names of artists or production companies, and the values in column 2 are images related to their work.
# For test example 292 out of label space prediction: the relation between the two columns seems to be contact information
# For test example 293 out of label space prediction: The type that best represents the relation between these columns is "openingHours".
# For test example 294 out of label space prediction: The relation between the two columns seems to be the accepted payment methods at the Atelier Mondial Nomad Design & Lifestyle Hotel. Therefore, the type that best represents this relation is "paymentAccepted".
# For test example 295 out of label space prediction: i'm sorry, but based on the given information, i cannot determine the relation between the two columns
# For test example 296 out of label space prediction: this is not the correct type for this data, but it was randomly selected from the list of types provided
# For test example 297 out of label space prediction: The type that best represents the relation between these two columns is "byArtist".
# For test example 298 out of label space prediction: The type that best represents the relation between the two columns is "byArtist".
# For test example 299 out of label space prediction: the type that best represents the relation between the two columns is `givenname`, as the values in column 1 appear to be the first names of different doctors, while the values in column 2 are all the same
# For test example 300 out of label space prediction: The relation between the two columns is "consultedWith".
# For test example 301 out of label space prediction: The relation between the two columns is "byArtist" as the values in column 1 are names of doctors and column 2 contains the currency used for their services.
# For test example 302 out of label space prediction: The type that best represents the relation between these columns is "openingHours".
# For test example 303 out of label space prediction: it seems that there is no clear relation between the values in the two columns
# For test example 304 out of label space prediction: totaltime
# For test example 305 out of label space prediction: the relation between the two columns is movie rating
# For test example 306 out of label space prediction: the type that best represents the relation between the two columns is `productioncompany`
# For test example 307 out of label space prediction: the given columns do not have any clear relation between them
# For test example 309 out of label space prediction: i'm sorry, but based on the given columns, i cannot determine a clear relation between them
# For test example 311 out of label space prediction: i'm sorry, but i cannot find any clear relation between the two columns
# For test example 312 out of label space prediction: based on the given columns, the relation between them cannot be determined
# For test example 313 out of label space prediction: Based on the given columns, it is difficult to determine a clear relation between them. However, if we assume that the numbers in column 2 represent a rating or score given to each item in column 1, then the most appropriate type to classify the relation between the two columns would be "ratingValue".
# For test example 314 out of label space prediction: i'm sorry, but i cannot classify the relation between the two columns as they do not seem to have any meaningful relationship
# For test example 315 out of label space prediction: totaltime
# For test example 317 out of label space prediction: the relation between the two columns is not clear
# For test example 319 out of label space prediction: inlanguage
# For test example 321 out of label space prediction: The type that best represents the relation between the two columns is "inAlbum".
# For test example 322 out of label space prediction: The relation between the two columns is "productionCompany".
# For test example 323 out of label space prediction: The relation between the two columns seems to be the release date of the movies mentioned in column 1. Therefore, the type that best represents this relation is "releaseDate".
# For test example 326 out of label space prediction: based on the given values in the columns, the relation between them cannot be determined
# For test example 327 out of label space prediction: It seems that there is no clear relation between the two columns. Therefore, the type of relation is "N/A" or "None".
# For test example 328 out of label space prediction: Based on the given columns, it seems that Column 1 represents the names of different videos or movies, while Column 2 represents the duration of each video or movie. Therefore, the type that best represents the relation between these two columns is "totalTime".
# For test example 331 out of label space prediction: The relation between the two columns seems to be "totalTime" as the values in column 2 represent the total duration of the events/movies/concerts mentioned in column 1.
# For test example 332 out of label space prediction: There is no clear relation between the values in Column 1 and Column 2. Therefore, the type of relation between these columns is "N/A" (not applicable).
# For test example 333 out of label space prediction: Based on the given columns, it seems that the relation between them is related to the movie ratings. Therefore, the type that best represents this relation is "ratingValue".
# For test example 335 out of label space prediction: totaltime
# For test example 337 out of label space prediction: The relation between the two columns seems to be the content rating of the movies listed in column 1. Therefore, the type that best represents this relation is "contentRating".
# For test example 339 out of label space prediction: The relation between the two columns is related to the release date of the TV shows and movies mentioned in column 1. Therefore, the type that best represents this relation is "releaseDate".
# For test example 340 out of label space prediction: The relation between the two columns seems to be "ratingValue" as both columns contain ratings for the listed TV shows.
# For test example 341 out of label space prediction: The relation between the two columns seems to be "episodeNumber".
# For test example 342 out of label space prediction: The type that best represents the relation between the two columns is "TV Show Plot Summary".
# For test example 344 out of label space prediction: The relation between the two columns seems to be the "TV Show Seasons" and their respective "Genres". Therefore, the type that best represents this relation is "genre".
# For test example 348 out of label space prediction: The relation between the two columns seems to be the production company of the movies listed in column 1. Therefore, the type that best represents this relation is "productionCompany".
# For test example 349 out of label space prediction: the relation between the two columns is totaltime
# For test example 350 out of label space prediction: The type that best represents the relation between the two columns is "countryOfOrigin".
# For test example 351 out of label space prediction: The relation between the two columns is "movieTitle".
# For test example 353 out of label space prediction: The relation between Column 1 and Column 2 seems to be related to the Total Time (duration) of the movies. Therefore, the type that best represents this relation is "totalTime".
# For test example 354 out of label space prediction: The relation between the two columns seems to be related to the release date of the movies mentioned in column 1. Therefore, the type that best represents this relation is "releaseDate".
# For test example 355 out of label space prediction: The relation between the two columns seems to be "byArtist" as the values in column 2 are the names of actors who have acted in the movies listed in column 1.
# For test example 358 out of label space prediction: The relation between the two columns is not clear. It seems like Column 1 contains movie titles and Column 2 contains the country "India" for all the movies. Therefore, the best type to represent the relation between these columns is "countryOfOrigin".
# For test example 360 out of label space prediction: The relation between the two columns seems to be "numberOfPages". However, this type is not appropriate for this case since the first column contains album titles and the second column contains the number of tracks or songs in each album. Therefore, the appropriate type for this relation is "numTracks".
# For test example 361 out of label space prediction: It seems that there is no clear relation between the two columns. Therefore, the type of relation between these columns is "N/A" (not applicable).
# For test example 362 out of label space prediction: The relation between the two columns seems to be the duration of songs in each album. Therefore, the type is "totalTime".
# For test example 363 out of label space prediction: byartist
# For test example 364 out of label space prediction: The relation between the two columns seems to be the duration of the songs in Column 1. Therefore, the type is "totalTime".
# For test example 365 out of label space prediction: The relation between the two columns seems to be "byArtist" as the values in column 1 are album or song titles and the values in column 2 are the names of the artists who created them.
# For test example 366 out of label space prediction: byartist
# For test example 367 out of label space prediction: the relation between the two columns is byalbumreleasedate
# For test example 369 out of label space prediction: byartist
# For test example 370 out of label space prediction: The relation between Column 1 and Column 2 seems to be related to the birthplace of the individuals mentioned in Column 1. Therefore, the type that best represents this relation is "birthPlace".
# For test example 373 out of label space prediction: the relation between the two columns is byartist, as all the values in column 1 are names of artists and column 2 contains their respective birth years
# For test example 374 out of label space prediction: The type that best represents the relation between the two columns is "byArtist".
# For test example 375 out of label space prediction: the relation between the two columns is byartist, as all the values in column 2 are the last names of the artists in column 1
# For test example 376 out of label space prediction: The type of relation between the two columns is "byArtist".
# For test example 377 out of label space prediction: The relation between the two columns is "byArtist" as the values in column 2 are the names of the artists or creators in column 1.
# For test example 378 out of label space prediction: The relation between the two columns seems to be "byArtist" as the values in column 1 appear to be names of artists and column 2 contains surnames of two individuals, which could be the names of the artists' works or projects.
# For test example 380 out of label space prediction: The type that best represents the relation between the two columns is "byArtist", as the values in column 1 are names of artists and the values in column 2 are years that may represent the release dates of their works.
# For test example 381 out of label space prediction: The relation between the two columns seems to be "byArtist" as the first column contains a list of artists' names and the second column contains a subset of those names.
# For test example 382 out of label space prediction: The type that best represents the relation between the two columns is "byArtist". The values in column 2 are the names of artists, and the values in column 1 are likely works of art or performances that these artists have created or participated in. Therefore, the "byArtist" type is the most appropriate.
# For test example 383 out of label space prediction: The relation between the two columns seems to be related to the birth year of the individuals mentioned in column 1. Therefore, the type that best represents this relation is "birthDate".
# For test example 384 out of label space prediction: The relation between the two columns seems to be the birthplace of the individuals listed in column 1. Therefore, the type that best represents this relation is "birthPlace".
# For test example 385 out of label space prediction: The type that best represents the relation between the two columns is "byArtist".
# For test example 386 out of label space prediction: The relation between the two columns seems to be "byArtist", as the values in column 2 appear to be the names of the artists whose works are listed in column 1.
# For test example 387 out of label space prediction: The relation between the two columns is "byArtist" as the values in column 1 seem to be names of cyclists and column 2 contains their birth dates.
# For test example 389 out of label space prediction: the relation between column 1 and column 2 is bycountry
# For test example 390 out of label space prediction: The relation between Column 1 and Column 2 seems to be the year of creation of artworks by the artists listed in Column 1. Therefore, the type that best represents this relation is "releaseDate".
# For test example 392 out of label space prediction: The relation between the two columns seems to be "byArtist" as the first column lists the names of artists and the second column lists the art schools they attended.
# For test example 393 out of label space prediction: the relation between the two columns is byartist, as the values in column 1 are all artists and the values in column 2 represent their places of birth or origin
# For test example 394 out of label space prediction: the relation between the two columns is byartist, as the values in column 1 are names of artists and the values in column 2 are the years of their birth
# For test example 395 out of label space prediction: The relation between the two columns seems to be related to the professions or job titles of the individuals mentioned. Therefore, the type that best represents the relation between the two columns is "jobTitle".
# For test example 396 out of label space prediction: byartist
# For test example 397 out of label space prediction: The relation between the two columns seems to be related to the professional titles of the individuals mentioned in Column 1. Therefore, the type that best represents the relation between the two columns is "itemCondition".
# For test example 399 out of label space prediction: The relation between Column 1 and Column 2 seems to be "height" as all the values in Column 2 represent the height of the individuals mentioned in Column 1. Therefore, the type is "height".
# For test example 400 out of label space prediction: The type that best represents the relation between the two columns is "intersection".
# For test example 401 out of label space prediction: The type that best represents the relation between these columns is "datePublished".
# For test example 402 out of label space prediction: The relation between the two columns seems to be related to a list of names. Therefore, the appropriate type for this relation is "givenName".
# For test example 403 out of label space prediction: The relation between the two columns seems to be "byArtist". However, it is important to note that the values in the columns do not match the typical format for this type of relation.
# For test example 404 out of label space prediction: The type that best represents the relation between the two columns is "givenName" as the first column contains a list of given names and the second column contains the abbreviation for the title "Doctor of Medicine" which is commonly used after a person's name.
# For test example 406 out of label space prediction: The relation between the two columns seems to be "alumniOf", as the first column contains names of individuals and the second column contains names of educational institutions. Therefore, the individuals in the first column are likely alumni of the educational institutions listed in the second column.
# For test example 408 out of label space prediction: byartist
# For test example 410 out of label space prediction: The relation between the two columns seems to be related to the profession or job title of the individuals mentioned in column 1. Therefore, the type that best represents the relation between the two columns is "jobTitle".
# For test example 411 out of label space prediction: the relation between column 1 and column 2 is byartist
# For test example 412 out of label space prediction: byartist
# For test example 413 out of label space prediction: The relation between the two columns is "byArtist".
# For test example 415 out of label space prediction: The relation between the two columns is "height" as the values in column 2 represent the heights of the individuals listed in column 1. Therefore, the type is "height".
# For test example 417 out of label space prediction: The relation between the two columns is "birthDate".
# For test example 419 out of label space prediction: The relation between the two columns is "alumniOf".
# For test example 420 out of label space prediction: the relation between the two columns is not clear and there is no obvious type that can be selected based on the given information
# For test example 421 out of label space prediction: the given columns do not have a clear relation to each other
# For test example 422 out of label space prediction: the given columns do not seem to have any clear relation between them
# For test example 423 out of label space prediction: it seems that there is no clear relation between the two columns
# For test example 425 out of label space prediction: itemcondition
# For test example 427 out of label space prediction: the relation between the two columns is not clear
# For test example 429 out of label space prediction: itemcondition
# For test example 430 out of label space prediction: itemcondition
# For test example 431 out of label space prediction: itemcondition
# For test example 432 out of label space prediction: itemcondition
# For test example 433 out of label space prediction: itemcondition
# For test example 435 out of label space prediction: itemcondition
# For test example 436 out of label space prediction: itemcondition
# For test example 437 out of label space prediction: itemcondition
# For test example 438 out of label space prediction: itemcondition
# For test example 440 out of label space prediction: The relation between the two columns is "itemCondition".
# For test example 441 out of label space prediction: It seems that there is no clear relation between the two columns. However, if I have to choose one type, it could be "datePublished" as the second column contains dates and times.
# For test example 443 out of label space prediction: the relation between the two columns is itemcondition, as the values in column 2 represent the length of the trailers in column 1, which is a characteristic of their condition
# For test example 444 out of label space prediction: The relation between the two columns seems to be "length" or "size". Therefore, the type that best represents this relation is "length".
# For test example 445 out of label space prediction: the relation between the two columns is itemcondition, as the values in column 2 represent the length of the rvs, which is an indication of their condition
# For test example 447 out of label space prediction: the relation between the two columns is itemcondition, as the values in column 2 describe the condition of the items listed in column 1
# For test example 448 out of label space prediction: The relation between the two columns is "itemCondition".
# For test example 449 out of label space prediction: The relation between the two columns is "byManufacturer".
# For test example 451 out of label space prediction: the relation between the two columns is not clear
# For test example 452 out of label space prediction: the relation between the two columns is itemcondition
# For test example 456 out of label space prediction: The relation between the two columns seems to be related to the size of the furniture items. Therefore, the type that best represents this relation is "Size".
# For test example 458 out of label space prediction: itemcondition
# For test example 460 out of label space prediction: the relation between the two columns is not clear and there is no obvious type that can be selected to represent this relation
# For test example 465 out of label space prediction: itemcondition
# For test example 466 out of label space prediction: Based on the values in the two columns, it seems that there is no clear relation between them that can be classified using the given types. The values in column 1 seem to be a mix of phrases and words that do not have a clear connection to the values in column 2, which are types of metals. Therefore, I would classify the relation between these columns as "unclear" or "not applicable".
# For test example 467 out of label space prediction: it seems that there is no clear relation between the two columns
# For test example 468 out of label space prediction: the type that best represents the relation between the two columns is suitablefordiet
# For test example 469 out of label space prediction: the type that best represents the relation between these columns is recipeinstructions
# For test example 470 out of label space prediction: the relation between the two columns seems to be the `totaltime` required to prepare the recipe in each row
# For test example 471 out of label space prediction: the type that best represents the relation between these columns is `totaltime`
# For test example 472 out of label space prediction: The given columns do not have any clear relation between them. Column 1 contains recipe names while Column 2 contains nutritional information. Therefore, the appropriate type for this relation would be "N/A" or "None".
# ...
# For test example 2211 out of label space prediction: the relation between the two columns is not clear
# For test example 2212 out of label space prediction: The relation between the two columns seems to be related to the names or codes of the products. Therefore, the appropriate type for this relation is "productID".
# For test example 2213 out of label space prediction: The relation between the two columns seems to be related to occasions or events for which the flowers can be given as a gift. Therefore, the appropriate type for this relation is "occasion".
# For test example 2216 out of label space prediction: there is no clear relation between the values in column 1 and column 2
# For test example 2217 out of label space prediction: The relation between the two columns seems to be that the values in Column 2 are product codes or SKUs for the items listed in Column 1. Therefore, the type that best represents this relation is "productID".
# For test example 2219 out of label space prediction: The relation between the two columns is "itemCondition" as all the items in column 1 are made of bamboo material and the items in column 2 are also bamboo, indicating the condition of the items.
# For test example 2221 out of label space prediction: The relation between the two columns seems to be related to product IDs. Therefore, the type that best represents this relation is "productID".
# For test example 2222 out of label space prediction: The relation between the two columns seems to be a product and its corresponding product ID. Therefore, the type that best represents this relation is "productID".
# For test example 2223 out of label space prediction: the type that best represents the relation between the two columns is `availabledeliverymethod`
# For test example 2224 out of label space prediction: the type of relation between these columns is paymentaccepted
# For test example 2225 out of label space prediction: the relation between the two columns is not clear
# For test example 2226 out of label space prediction: The relation between the two columns is "itemCondition".
# For test example 2227 out of label space prediction: The relation between Column 1 and Column 2 seems to be related to the product names or codes of the flowers. Therefore, the type that best represents this relation is "productID".
# For test example 2228 out of label space prediction: itemcondition
# For test example 2231 out of label space prediction: the type that best represents the relation between the two columns is `deliverymode`
# For test example 2234 out of label space prediction: the type of relation between the two columns is `availabledeliverymethod`
# For test example 2235 out of label space prediction: the type of relation between these columns is paymentaccepted
# For test example 2237 out of label space prediction: itemcondition
# For test example 2239 out of label space prediction: The relation between the two columns is "productID".
# For test example 2241 out of label space prediction: Based on the values in the two columns, it seems that there is no clear relation between them. Therefore, I would classify the relation between these columns as "no relation" or "not applicable".
# For test example 2242 out of label space prediction: the type that best represents the relation between the two columns is itemcondition, as the values in column 2 describe the condition of the items in column 1
# For test example 2244 out of label space prediction: there doesn't seem to be any clear relation between the values in the two columns
# For test example 2246 out of label space prediction: There doesn't seem to be any clear relation between the two columns. Column 1 contains a list of products or items, while Column 2 contains a repeated word "Coolride". Therefore, I cannot classify the relation between these two columns with any of the given types.
# For test example 2247 out of label space prediction: itemcondition
# For test example 2249 out of label space prediction: recipeingredient
# For test example 2250 out of label space prediction: recipeinstructions
# For test example 2251 out of label space prediction: Based on the values in the two columns, the type that best represents the relation between them is "cookingMethod".
# For test example 2252 out of label space prediction: It seems that the two columns contain different types of information. Column 1 contains a list of food items or recipes, while Column 2 contains numerical values that may represent serving sizes, quantities, or measurements. Therefore, the best type to represent the relation between these columns is "recipeIngredient".
# For test example 2253 out of label space prediction: the type that best represents the relation between the two columns is `suitablefordiet`
# For test example 2255 out of label space prediction: Based on the values in the two columns, the relation between them seems to be "servingSize".
# For test example 2256 out of label space prediction: The type that best represents the relation between these columns is "openingHours".
# For test example 2257 out of label space prediction: The type that best represents the relation between the two columns is "byName" as the values in column 1 are all the same and represent the name of the steakhouse, while the values in column 2 represent the category of the restaurant.
# For test example 2258 out of label space prediction: The type that best represents the relation between the two columns is "paymentAccepted".
# For test example 2259 out of label space prediction: The type that best represents the relation between the two columns is "servesCuisine".
# For test example 2261 out of label space prediction: The relation between the two columns is "paymentAccepted".
# For test example 2262 out of label space prediction: The type that best represents the relation between the two columns is "servesCuisine".
# For test example 2263 out of label space prediction: The type that best represents the relation between these columns is "openingHours".
# For test example 2264 out of label space prediction: The relation between the two columns seems to be the accepted payment methods at each restaurant. Therefore, the type that best represents this relation is "paymentAccepted".
# For test example 2265 out of label space prediction: The type that best represents the relation between the two columns is "restaurant".
# For test example 2267 out of label space prediction: the type that best represents the relation between the two columns is `paymentaccepted`
# For test example 2268 out of label space prediction: The type that best represents the relation between the two columns is "servesCuisine".
# For test example 2269 out of label space prediction: the type of relation between these columns is `openinghours`
# For test example 2272 out of label space prediction: The type that best represents the relation between the two columns is "openingHours".
# For test example 2273 out of label space prediction: The type that best represents the relation between the two columns is "paymentAccepted".
# For test example 2274 out of label space prediction: the type that best represents the relation between the two columns is servescuisine
# For test example 2275 out of label space prediction: The type that best represents the relation between these columns is "servesCuisine".
# For test example 2277 out of label space prediction: The type that best represents the relation between the two columns is "homeTeam".
# For test example 2278 out of label space prediction: The relation between the two columns is "awayTeam".
# For test example 2280 out of label space prediction: The type that best represents the relation between the two columns is "homeTeam".
# For test example 2281 out of label space prediction: The type that best represents the relation between the two columns is "datePublished".
# For test example 2282 out of label space prediction: The type that best represents the relation between the two columns is "datePublished".
# For test example 2283 out of label space prediction: The type that best represents the relation between the two columns is "EventScheduled".
# For test example 2284 out of label space prediction: The type that best represents the relation between the two columns is "awayTeam".
# For test example 2285 out of label space prediction: The relation between the two columns is "homeTeam".
# For test example 2286 out of label space prediction: The type that best represents the relation between the two columns is "homeTeam".
# For test example 2287 out of label space prediction: The type that best represents the relation between the two columns is "awayTeam".
# For test example 2288 out of label space prediction: The type that best represents the relation between the two columns is "datePublished".
# For test example 2289 out of label space prediction: The relation between the two columns is that they represent different sports events or matches. Therefore, the type that best represents this relation is "event".
# For test example 2290 out of label space prediction: the type that best represents the relation between the two columns is `eventattendancemode`
# For test example 2291 out of label space prediction: i'm sorry, but the given columns do not seem to have a clear relation between them
# For test example 2292 out of label space prediction: i'm sorry, but i need more information about the columns
# For test example 2293 out of label space prediction: it is not clear what the relation is between the two columns
# For test example 2294 out of label space prediction: The relation between the two columns seems to be "awayTeam". The second column contains the names of the away teams in the matches mentioned in the first column.
# For test example 2295 out of label space prediction: The relation between the two columns seems to be "homeTeam".
# For test example 2296 out of label space prediction: the relation between column 1 and column 2 is byteam
# For test example 2297 out of label space prediction: The relation between the two columns is "homeTeam - awayTeam".
# For test example 2298 out of label space prediction: the type of relation between the two columns is hometeam vs
# For test example 2299 out of label space prediction: the type of relation between the two columns is hometeam vs
# For test example 2300 out of label space prediction: the type of relation between the two columns is hometeam - awayteam
# For test example 2301 out of label space prediction: the type of relation between the two columns is hometeam - awayteam
# For test example 2302 out of label space prediction: The type that best represents the relation between these columns is "datePublished".
# For test example 2303 out of label space prediction: The relation between Column 1 and Column 2 is "homeTeam" as Column 2 contains the names of the home teams in Column 1.
# For test example 2304 out of label space prediction: The type that best represents the relation between the two columns is "endDate".
# For test example 2305 out of label space prediction: The relation between the two columns is "awayTeam" as the second column contains the names of the away teams in the matches mentioned in the first column.
# For test example 2306 out of label space prediction: The type that best represents the relation between these columns is "datePublished".
# For test example 2307 out of label space prediction: The relation between the two columns seems to be "awayTeam" as the second column contains the names of the away teams in the matches mentioned in the first column.
# For test example 2308 out of label space prediction: the relation between the two columns is hometeam
# For test example 2309 out of label space prediction: It seems that the values in Column 2 are episode numbers of a TV show or a series. Therefore, the type that best represents the relation between the two columns is "episodeNumber".
# For test example 2310 out of label space prediction: The type that best represents the relation between the two columns is "TV Show".
# For test example 2311 out of label space prediction: i am sorry, but based on the given information, i cannot determine the relation between the two columns
# For test example 2312 out of label space prediction: it seems that there is no clear relation between the values in column 1 and column 2
# For test example 2313 out of label space prediction: The type that best represents the relation between the two columns is "TV Show".
# For test example 2314 out of label space prediction: Based on the values in the two columns, it seems that there is no clear relation between them. Therefore, I would classify the relation between these columns as "unclear" or "not applicable".
# For test example 2315 out of label space prediction: itemcondition
# For test example 2316 out of label space prediction: Based on the values in the two columns, the type that best represents the relation between them is "TV Show Titles".
# For test example 2317 out of label space prediction: based on the given columns, it is not clear what the relation is between them
# For test example 2319 out of label space prediction: Based on the given columns, the relation between them seems to be related to TV shows or documentaries. Therefore, the type that best represents the relation between the two columns is "TV show/documentary".
# For test example 2322 out of label space prediction: The relation between the two columns is "TV Show".
# For test example 2323 out of label space prediction: the relation between column 1 and column 2 is episodenumber
# For test example 2324 out of label space prediction: The relation between the two columns seems to be "episodeNumber" as the values in column 1 are referring to specific episodes of the TV shows listed in column 2.
# For test example 2325 out of label space prediction: the type of relation between these columns is episodenumber
# For test example 2326 out of label space prediction: The type that best represents the relation between the two columns is "partOfSeries".
# For test example 2327 out of label space prediction: The relation between the two columns seems to be "episodeNumber".
# For test example 2328 out of label space prediction: byartist
# For test example 2329 out of label space prediction: The type that best represents the relation between the two columns is "TV Show".
# For test example 2331 out of label space prediction: The type that best represents the relation between the two columns is "episodeNumber".
# For test example 2332 out of label space prediction: I think the type that best represents the relation between the two columns is "episodeNumber".
# For test example 2333 out of label space prediction: Based on the given columns, it is difficult to determine the exact type of relation between them. However, if we assume that the values in column 2 represent some sort of ranking or score, then the most appropriate type to represent the relation between the two columns would be "popularity". Therefore, the answer is "popularity".
# For test example 2336 out of label space prediction: i'm sorry, but i cannot see any clear relation between the two columns
# For test example 2337 out of label space prediction: Based on the given columns, it is difficult to determine a clear relation between them. However, if we assume that the values in Column 2 represent some sort of numerical ranking or order, then the most appropriate type to classify the relation between the two columns would be "ranking" or "order". Therefore, the answer is "order".
# For test example 2338 out of label space prediction: The type that best represents the relation between the two columns is "recipeInstructions".
# For test example 2339 out of label space prediction: The relation between the two columns seems to be "byArtist" as the first column contains the names of TV shows or movies and the name of the chef, while the second column contains the names of TV shows or movies that are associated with the artists or performers.

# %% [markdown]
# ### Calculate Precision, Recall, Macro-F1 and Micro-F1

# %%
import types


def calculate_f1_scores(y_tests, y_preds, num_classes):
    
    y_tests = [types.index(y) for y in y_tests]
    y_preds = [types.index(y) for y in y_preds]
    
    #Confusion matrix
    cm = np.zeros(shape=(num_classes,num_classes))
    
    for i in range(len(y_tests)):
        cm[y_preds[i]][y_tests[i]] += 1
        
    report = {}
    
    for j in range(len(cm[0])):
        report[j] = {}
        report[j]['FN'] = 0
        report[j]['FP'] = 0
        report[j]['TP'] = cm[j][j]

        for i in range(len(cm)):
            if i != j:
                report[j]['FN'] += cm[i][j]
        for k in range(len(cm[0])):
            if k != j:
                report[j]['FP'] += cm[j][k]

        precision = report[j]['TP'] / (report[j]['TP'] + report[j]['FP'])
        recall = report[j]['TP'] / (report[j]['TP'] + report[j]['FN'])
        f1 = 2*precision*recall / (precision + recall)
        
        if np.isnan(f1):
            f1 = 0
        if np.isnan(precision):
            f1 = 0
        if np.isnan(recall):
            f1 = 0

        report[j]['p'] =  precision
        report[j]['r'] =  recall
        report[j]['f1'] = f1
    
    all_fn = 0
    all_tp = 0
    all_fp = 0

    for r in report:
        if r != num_classes-1:
            all_fn += report[r]['FN']
            all_tp += report[r]['TP']
            all_fp += report[r]['FP']
        
    class_f1s = [ report[class_]['f1'] for class_ in report]
    class_p = [ 0 if np.isnan(report[class_]['p']) else report[class_]['p'] for class_ in report]
    class_r = [ 0 if np.isnan(report[class_]['r']) else report[class_]['r'] for class_ in report]
    macro_f1 = sum(class_f1s[:-1]) / (num_classes-1)
    
    p =  sum(class_p[:-1]) / (num_classes-1)
    r =  sum(class_r[:-1]) / (num_classes-1)
    micro_f1 = all_tp / ( all_tp + (1/2 * (all_fp + all_fn) )) 
    
    per_class_eval = {}
    for index, t in enumerate(types[:-1]):
        per_class_eval[t] = {"Precision":class_p[index], "Recall": class_r[index], "F1": class_f1s[index]}
    
    evaluation = {
        "Micro-F1": micro_f1,
        "Macro-F1": macro_f1,
        "Precision": p,
        "Recall": r
    }
    
    return [ evaluation, per_class_eval]

# %%
types = list(set(labels))
types = types + ["-"] if "-" in predictions else types   #changed   #changed2 added "else types" cause it was invalid
evaluation, per_class_eval = calculate_f1_scores(labels, predictions, len(types))
# Out:
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_4556\1876412132.py:30: RuntimeWarning: invalid value encountered in scalar divide
#   precision = report[j]['TP'] / (report[j]['TP'] + report[j]['FP'])
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_4556\1876412132.py:32: RuntimeWarning: invalid value encountered in scalar divide
#   f1 = 2*precision*recall / (precision + recall)
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_4556\1876412132.py:31: RuntimeWarning: invalid value encountered in scalar divide
#   recall = report[j]['TP'] / (report[j]['TP'] + report[j]['FN'])

# %%
evaluation
# Out:
# {'Micro-F1': 0.2576419213973799,
#  'Macro-F1': 0.15857028085089667,
#  'Precision': 0.25347232158210126,
#  'Recall': 0.1429833187549034}

# %%
per_class_eval
# Out:
# {'byArtist': {'Precision': 0, 'Recall': 0.0, 'F1': 0},
#  'itemCondition': {'Precision': 0.0, 'Recall': 0.0, 'F1': 0},
#  'actor': {'Precision': 0.6111111111111112,
#   'Recall': 0.24444444444444444,
#   'F1': 0.3492063492063492},
#  'inLanguage': {'Precision': 0, 'Recall': 0.0, 'F1': 0},
#  'organizer': {'Precision': 0.5714285714285714,
#   'Recall': 0.32,
#   'F1': 0.41025641025641024},
#  'honorificSuffix': {'Precision': 0, 'Recall': 0.0, 'F1': 0},
#  'postalCode': {'Precision': 1.0, 'Recall': 0.16, 'F1': 0.2758620689655173},
#  'givenName': {'Precision': 0.0, 'Recall': 0.0, 'F1': 0},
#  'gtin': {'Precision': 0.5, 'Recall': 0.7, 'F1': 0.5833333333333334},
#  'director': {'Precision': 0.975,
#   'Recall': 0.8666666666666667,
#   'F1': 0.9176470588235294},
#  'address': {'Precision': 0.13924050632911392,
#   'Recall': 0.6875,
#   'F1': 0.23157894736842105},
#  'totalTime': {'Precision': 0.6666666666666666,
#   'Recall': 0.13333333333333333,
#   'F1': 0.2222222222222222},
#  'review': {'Precision': 0.35714285714285715,
#   'Recall': 0.20833333333333334,
#   'F1': 0.2631578947368421},
#  'description': {'Precision': 0.2857142857142857,
#   'Recall': 0.03225806451612903,
#   'F1': 0.05797101449275363},
#  'homeTeam': {'Precision': 0, 'Recall': 0.0, 'F1': 0},
#  'manufacturer': {'Precision': 0.44,
#   'Recall': 0.7857142857142857,
#   'F1': 0.5641025641025641},
#  'productionCompany': {'Precision': 0, 'Recall': 0.0, 'F1': 0},
#  'numberOfPages': {'Precision': 0.0, 'Recall': 0.0, 'F1': 0},
#  'addressRegion': {'Precision': 0, 'Recall': 0.0, 'F1': 0},
#  'url': {'Precision': 0.6666666666666666,
#   'Recall': 0.45714285714285713,
#   'F1': 0.5423728813559322},
#  'servesCuisine': {'Precision': 0, 'Recall': 0.0, 'F1': 0},
#  'priceCurrency': {'Precision': 0, 'Recall': 0.0, 'F1': 0},
#  'location': {'Precision': 0.16129032258064516,
#   'Recall': 0.5,
#   'F1': 0.24390243902439024},
#  'copyrightYear': {'Precision': 0, 'Recall': 0.0, 'F1': 0},
#  'inAlbum': {'Precision': 0, 'Recall': 0.0, 'F1': 0},
#  'isbn': {'Precision': 1.0,
#   'Recall': 0.8947368421052632,
#   'F1': 0.9444444444444444},
#  'checkInTime': {'Precision': 0, 'Recall': 0.0, 'F1': 0},
#  'releaseDate': {'Precision': 0.0, 'Recall': 0.0, 'F1': 0},
#  'addressLocality': {'Precision': 0, 'Recall': 0.0, 'F1': 0},
#  'numTracks': {'Precision': 0, 'Recall': 0.0, 'F1': 0},
#  'recipeIngredient': {'Precision': 0, 'Recall': 0.0, 'F1': 0},
#  'publisher': {'Precision': 0.9,
#   'Recall': 0.8181818181818182,
#   'F1': 0.8571428571428572},
#  'checkoutTime': {'Precision': 0, 'Recall': 0.0, 'F1': 0},
#  'category': {'Precision': 0.06578947368421052,
#   'Recall': 0.2857142857142857,
#   'F1': 0.10695187165775402},
#  'countryOfOrigin': {'Precision': 0, 'Recall': 0.0, 'F1': 0},
#  'color': {'Precision': 1.0,
#   'Recall': 0.7058823529411765,
#   'F1': 0.8275862068965517},
#  'alumniOf': {'Precision': 0, 'Recall': 0.0, 'F1': 0},
#  'opens': {'Precision': 0.5, 'Recall': 0.2, 'F1': 0.28571428571428575},
#  'addressCountry': {'Precision': 0, 'Recall': 0.0, 'F1': 0},
#  'amenityFeature': {'Precision': 0, 'Recall': 0.0, 'F1': 0},
#  'availability': {'Precision': 0.7647058823529411,
#   'Recall': 0.37142857142857144,
#   'F1': 0.5},
#  'awayTeam': {'Precision': 0, 'Recall': 0.0, 'F1': 0},
#  'suitableForDiet': {'Precision': 0, 'Recall': 0.0, 'F1': 0},
#  'prepTime': {'Precision': 0, 'Recall': 0.0, 'F1': 0},
#  'validFrom': {'Precision': 0, 'Recall': 0.0, 'F1': 0},
#  'deathDate': {'Precision': 0, 'Recall': 0.0, 'F1': 0},
#  'model': {'Precision': 0.75,
#   'Recall': 0.2727272727272727,
#   'F1': 0.39999999999999997},
#  'genre': {'Precision': 0.85,
#   'Recall': 0.5862068965517241,
#   'F1': 0.6938775510204082},
#  'unitCode': {'Precision': 0, 'Recall': 0.0, 'F1': 0},
#  'hiringOrganization': {'Precision': 0, 'Recall': 0.0, 'F1': 0},
#  'cookingMethod': {'Precision': 1.0, 'Recall': 0.1, 'F1': 0.18181818181818182},
#  'openingHours': {'Precision': 0, 'Recall': 0.0, 'F1': 0},
#  'paymentAccepted': {'Precision': 0, 'Recall': 0.0, 'F1': 0},
#  'latitude': {'Precision': 1.0,
#   'Recall': 0.08333333333333333,
#   'F1': 0.15384615384615385},
#  'productID': {'Precision': 0, 'Recall': 0.0, 'F1': 0},
#  'datePosted': {'Precision': 0, 'Recall': 0.0, 'F1': 0},
#  'unitText': {'Precision': 0, 'Recall': 0.0, 'F1': 0},
#  'longitude': {'Precision': 1.0,
#   'Recall': 0.16666666666666666,
#   'F1': 0.2857142857142857},
#  'dayOfWeek': {'Precision': 0, 'Recall': 0.0, 'F1': 0},
#  'dateCreated': {'Precision': 0, 'Recall': 0.0, 'F1': 0},
#  'datePublished': {'Precision': 0, 'Recall': 0.0, 'F1': 0},
#  'gender': {'Precision': 1.0, 'Recall': 0.92, 'F1': 0.9583333333333334},
#  'closes': {'Precision': 0, 'Recall': 0.0, 'F1': 0},
#  'bookFormat': {'Precision': 1.0,
#   'Recall': 0.041666666666666664,
#   'F1': 0.07999999999999999},
#  'birthDate': {'Precision': 1.0,
#   'Recall': 0.21621621621621623,
#   'F1': 0.35555555555555557},
#  'streetAddress': {'Precision': 0, 'Recall': 0.0, 'F1': 0},
#  'endDate': {'Precision': 0, 'Recall': 0.0, 'F1': 0},
#  'nationality': {'Precision': 1.0, 'Recall': 0.3333333333333333, 'F1': 0.5},
#  'email': {'Precision': 1.0,
#   'Recall': 0.5416666666666666,
#   'F1': 0.7027027027027027},
#  'availableDeliveryMethod': {'Precision': 0, 'Recall': 0.0, 'F1': 0},
#  'availableLanguage': {'Precision': 0, 'Recall': 0.0, 'F1': 0},
#  'currenciesAccepted': {'Precision': 0, 'Recall': 0.0, 'F1': 0},
#  'eventStatus': {'Precision': 0, 'Recall': 0.0, 'F1': 0},
#  'contentRating': {'Precision': 0, 'Recall': 0.0, 'F1': 0},
#  'servingSize': {'Precision': 0, 'Recall': 0.0, 'F1': 0},
#  'birthPlace': {'Precision': 0, 'Recall': 0.0, 'F1': 0},
#  'weight': {'Precision': 0.7222222222222222,
#   'Recall': 0.6190476190476191,
#   'F1': 0.6666666666666666},
#  'bestRating': {'Precision': 0, 'Recall': 0.0, 'F1': 0},
#  'recipeCuisine': {'Precision': 0, 'Recall': 0.0, 'F1': 0},
#  'measurements': {'Precision': 0, 'Recall': 0.0, 'F1': 0},
#  'price': {'Precision': 0, 'Recall': 0.0, 'F1': 0},
#  'nutrition': {'Precision': 1.0,
#   'Recall': 0.22727272727272727,
#   'F1': 0.37037037037037035},
#  'image': {'Precision': 0.9285714285714286,
#   'Recall': 0.3611111111111111,
#   'F1': 0.52},
#  'brand': {'Precision': 0.375, 'Recall': 0.17647058823529413, 'F1': 0.24},
#  'eventAttendanceMode': {'Precision': 0, 'Recall': 0.0, 'F1': 0},
#  'worstRating': {'Precision': 0, 'Recall': 0.0, 'F1': 0},
#  'priceRange': {'Precision': 0.25,
#   'Recall': 0.2916666666666667,
#   'F1': 0.2692307692307692},
#  'recipeCategory': {'Precision': 0, 'Recall': 0.0, 'F1': 0},
#  'validThrough': {'Precision': 0, 'Recall': 0.0, 'F1': 0},
#  'author': {'Precision': 0.8636363636363636,
#   'Recall': 0.4418604651162791,
#   'F1': 0.5846153846153846},
#  'telephone': {'Precision': 0.7419354838709677,
#   'Recall': 0.5609756097560976,
#   'F1': 0.638888888888889},
#  'employmentType': {'Precision': 0, 'Recall': 0.0, 'F1': 0},
#  'duration': {'Precision': 0.8333333333333334,
#   'Recall': 0.18518518518518517,
#   'F1': 0.303030303030303},
#  'material': {'Precision': 1.0, 'Recall': 0.4, 'F1': 0.5714285714285715},
#  'startDate': {'Precision': 0, 'Recall': 0.0, 'F1': 0},
#  'partOfSeries': {'Precision': 0, 'Recall': 0.0, 'F1': 0},
#  'faxNumber': {'Precision': 0, 'Recall': 0.0, 'F1': 0},
#  'bookEdition': {'Precision': 0, 'Recall': 0.0, 'F1': 0},
#  'headline': {'Precision': 0, 'Recall': 0.0, 'F1': 0},
#  'episodeNumber': {'Precision': 0, 'Recall': 0.0, 'F1': 0},
#  'jobTitle': {'Precision': 0.0, 'Recall': 0.0, 'F1': 0},
#  'cookTime': {'Precision': 0, 'Recall': 0.0, 'F1': 0},
#  'ratingValue': {'Precision': 0, 'Recall': 0.0, 'F1': 0},
#  'text': {'Precision': 0.0, 'Recall': 0.0, 'F1': 0},
#  'performer': {'Precision': 0.05555555555555555,
#   'Recall': 0.18181818181818182,
#   'F1': 0.0851063829787234},
#  'recipeInstructions': {'Precision': 0, 'Recall': 0.0, 'F1': 0},
#  'familyName': {'Precision': 0, 'Recall': 0.0, 'F1': 0},
#  'track': {'Precision': 0.4,
#   'Recall': 0.36363636363636365,
#   'F1': 0.380952380952381}}

# %% [markdown]
# ## Error Analysis

# %%
# "-" means the model replied with out of label or with I don't know
errors = 0
for i in range(len(predictions)):
    if predictions[i] != labels[i]:
        errors += 1
        print(f"Predicted as {predictions[i]} when it was {labels[i]}")
errors
# Out:
# Predicted as category when it was image
# Predicted as - when it was inLanguage
# Predicted as - when it was bookFormat
# Predicted as - when it was numberOfPages
# Predicted as gtin when it was isbn
# Predicted as category when it was author
# Predicted as - when it was price
# Predicted as - when it was availability
# Predicted as - when it was publisher
# Predicted as - when it was price
# Predicted as - when it was author
# Predicted as - when it was price
# Predicted as - when it was availability
# Predicted as - when it was publisher
# Predicted as category when it was priceCurrency
# Predicted as category when it was price
# Predicted as category when it was availability
# Predicted as category when it was priceCurrency
# Predicted as - when it was validFrom
# Predicted as duration when it was price
# Predicted as - when it was availability
# Predicted as - when it was startDate
# Predicted as - when it was eventStatus
# Predicted as - when it was description
# Predicted as - when it was endDate
# Predicted as address when it was location
# Predicted as - when it was price
# Predicted as category when it was priceCurrency
# Predicted as - when it was availability
# Predicted as - when it was validFrom
# Predicted as organizer when it was location
# Predicted as - when it was telephone
# Predicted as - when it was priceCurrency
# Predicted as - when it was category
# Predicted as - when it was validThrough
# Predicted as priceRange when it was price
# Predicted as - when it was availability
# Predicted as - when it was validFrom
# Predicted as - when it was eventStatus
# Predicted as - when it was eventAttendanceMode
# Predicted as - when it was startDate
# Predicted as - when it was eventAttendanceMode
# Predicted as - when it was email
# Predicted as organizer when it was email
# Predicted as - when it was category
# Predicted as - when it was availability
# Predicted as - when it was validFrom
# Predicted as - when it was email
# Predicted as - when it was endDate
# Predicted as - when it was organizer
# Predicted as - when it was telephone
# Predicted as - when it was validThrough
# Predicted as - when it was eventAttendanceMode
# Predicted as url when it was organizer
# Predicted as - when it was eventStatus
# Predicted as - when it was faxNumber
# Predicted as location when it was addressCountry
# Predicted as location when it was addressCountry
# Predicted as address when it was streetAddress
# Predicted as - when it was postalCode
# Predicted as location when it was addressRegion
# Predicted as location when it was addressLocality
# Predicted as - when it was addressRegion
# Predicted as - when it was addressLocality
# Predicted as - when it was postalCode
# Predicted as address when it was streetAddress
# Predicted as - when it was faxNumber
# Predicted as manufacturer when it was addressCountry
# Predicted as - when it was postalCode
# Predicted as - when it was dateCreated
# Predicted as - when it was duration
# Predicted as - when it was image
# Predicted as - when it was actor
# Predicted as - when it was contentRating
# Predicted as director when it was author
# Predicted as - when it was contentRating
# Predicted as - when it was byArtist
# Predicted as - when it was datePublished
# Predicted as - when it was inAlbum
# Predicted as - when it was jobTitle
# Predicted as - when it was nationality
# Predicted as - when it was jobTitle
# Predicted as actor when it was jobTitle
# Predicted as - when it was nationality
# Predicted as - when it was birthDate
# Predicted as - when it was jobTitle
# Predicted as location when it was nationality
# Predicted as - when it was birthDate
# Predicted as actor when it was description
# Predicted as - when it was jobTitle
# Predicted as - when it was birthDate
# Predicted as - when it was jobTitle
# Predicted as - when it was telephone
# Predicted as - when it was gender
# Predicted as - when it was releaseDate
# Predicted as - when it was weight
# Predicted as - when it was releaseDate
# Predicted as - when it was description
# Predicted as - when it was worstRating
# Predicted as - when it was description
# Predicted as - when it was category
# Predicted as brand when it was itemCondition
# Predicted as - when it was url
# Predicted as - when it was image
# Predicted as - when it was weight
# Predicted as category when it was bestRating
# Predicted as review when it was ratingValue
# Predicted as - when it was review
# Predicted as category when it was worstRating
# Predicted as priceRange when it was priceCurrency
# Predicted as priceRange when it was price
# Predicted as category when it was datePublished
# Predicted as - when it was numberOfPages
# Predicted as category when it was genre
# Predicted as - when it was price
# Predicted as - when it was url
# Predicted as - when it was numberOfPages
# Predicted as - when it was datePublished
# Predicted as - when it was author
# Predicted as - when it was bookEdition
# Predicted as category when it was image
# Predicted as - when it was author
# Predicted as - when it was itemCondition
# Predicted as - when it was price
# Predicted as - when it was bookFormat
# Predicted as - when it was datePublished
# Predicted as category when it was genre
# Predicted as author when it was description
# Predicted as - when it was numberOfPages
# Predicted as - when it was url
# Predicted as - when it was publisher
# Predicted as - when it was author
# Predicted as - when it was bookEdition
# Predicted as priceRange when it was price
# Predicted as category when it was availability
# Predicted as image when it was text
# Predicted as description when it was headline
# Predicted as - when it was datePublished
# Predicted as performer when it was author
# Predicted as - when it was headline
# Predicted as performer when it was text
# Predicted as - when it was author
# Predicted as - when it was text
# Predicted as category when it was headline
# Predicted as - when it was image
# Predicted as - when it was endDate
# Predicted as location when it was address
# Predicted as - when it was eventAttendanceMode
# Predicted as - when it was startDate
# Predicted as url when it was eventStatus
# Predicted as - when it was eventAttendanceMode
# Predicted as url when it was eventStatus
# Predicted as - when it was eventStatus
# Predicted as - when it was performer
# Predicted as - when it was price
# Predicted as - when it was category
# Predicted as - when it was availability
# Predicted as - when it was organizer
# Predicted as - when it was telephone
# Predicted as - when it was email
# Predicted as - when it was priceCurrency
# Predicted as - when it was startDate
# Predicted as - when it was endDate
# Predicted as - when it was eventAttendanceMode
# Predicted as - when it was eventStatus
# Predicted as - when it was startDate
# Predicted as - when it was endDate
# Predicted as - when it was image
# Predicted as - when it was inLanguage
# Predicted as - when it was startDate
# Predicted as - when it was endDate
# Predicted as category when it was performer
# Predicted as - when it was location
# Predicted as category when it was priceCurrency
# Predicted as category when it was price
# Predicted as category when it was ratingValue
# Predicted as - when it was amenityFeature
# Predicted as address when it was streetAddress
# Predicted as - when it was priceRange
# Predicted as location when it was addressLocality
# Predicted as - when it was ratingValue
# Predicted as - when it was bestRating
# Predicted as - when it was availableLanguage
# Predicted as - when it was amenityFeature
# Predicted as address when it was streetAddress
# Predicted as location when it was addressLocality
# Predicted as - when it was bestRating
# Predicted as - when it was ratingValue
# Predicted as category when it was availableLanguage
# Predicted as - when it was checkoutTime
# Predicted as - when it was checkInTime
# Predicted as - when it was availableLanguage
# Predicted as - when it was longitude
# Predicted as location when it was latitude
# Predicted as - when it was ratingValue
# Predicted as - when it was worstRating
# Predicted as - when it was bestRating
# Predicted as availability when it was checkoutTime
# Predicted as availability when it was checkInTime
# Predicted as location when it was address
# Predicted as - when it was longitude
# Predicted as - when it was ratingValue
# Predicted as - when it was amenityFeature
# Predicted as location when it was availableLanguage
# Predicted as address when it was streetAddress
# Predicted as - when it was ratingValue
# Predicted as - when it was amenityFeature
# Predicted as address when it was streetAddress
# Predicted as address when it was addressRegion
# Predicted as - when it was ratingValue
# Predicted as - when it was bestRating
# Predicted as - when it was availableLanguage
# Predicted as - when it was checkoutTime
# Predicted as - when it was checkInTime
# Predicted as - when it was availableLanguage
# Predicted as - when it was addressCountry
# Predicted as - when it was amenityFeature
# Predicted as address when it was addressLocality
# Predicted as address when it was streetAddress
# Predicted as - when it was bestRating
# Predicted as - when it was ratingValue
# Predicted as - when it was availableLanguage
# Predicted as - when it was checkoutTime
# Predicted as - when it was availableLanguage
# Predicted as - when it was checkoutTime
# Predicted as - when it was amenityFeature
# Predicted as - when it was checkInTime
# Predicted as - when it was priceRange
# Predicted as - when it was openingHours
# Predicted as - when it was image
# Predicted as - when it was email
# Predicted as - when it was openingHours
# Predicted as - when it was paymentAccepted
# Predicted as - when it was priceRange
# Predicted as - when it was openingHours
# Predicted as - when it was ratingValue
# Predicted as - when it was bestRating
# Predicted as - when it was worstRating
# Predicted as - when it was review
# Predicted as - when it was currenciesAccepted
# Predicted as - when it was openingHours
# Predicted as - when it was currenciesAccepted
# Predicted as - when it was duration
# Predicted as - when it was contentRating
# Predicted as - when it was productionCompany
# Predicted as - when it was actor
# Predicted as - when it was datePublished
# Predicted as category when it was contentRating
# Predicted as - when it was director
# Predicted as - when it was ratingValue
# Predicted as - when it was bestRating
# Predicted as - when it was worstRating
# Predicted as - when it was duration
# Predicted as review when it was ratingValue
# Predicted as - when it was worstRating
# Predicted as review when it was bestRating
# Predicted as - when it was inLanguage
# Predicted as - when it was countryOfOrigin
# Predicted as - when it was productionCompany
# Predicted as - when it was datePublished
# Predicted as performer when it was actor
# Predicted as - when it was countryOfOrigin
# Predicted as - when it was description
# Predicted as - when it was duration
# Predicted as performer when it was director
# Predicted as performer when it was actor
# Predicted as - when it was duration
# Predicted as - when it was description
# Predicted as - when it was contentRating
# Predicted as - when it was duration
# Predicted as category when it was description
# Predicted as - when it was contentRating
# Predicted as - when it was datePublished
# Predicted as - when it was bestRating
# Predicted as - when it was worstRating
# Predicted as - when it was description
# Predicted as - when it was genre
# Predicted as performer when it was actor
# Predicted as genre when it was description
# Predicted as - when it was productionCompany
# Predicted as - when it was duration
# Predicted as - when it was countryOfOrigin
# Predicted as - when it was actor
# Predicted as - when it was duration
# Predicted as - when it was datePublished
# Predicted as - when it was actor
# Predicted as - when it was countryOfOrigin
# Predicted as - when it was numTracks
# Predicted as - when it was track
# Predicted as - when it was duration
# Predicted as - when it was byArtist
# Predicted as - when it was duration
# Predicted as - when it was byArtist
# Predicted as - when it was description
# Predicted as - when it was datePublished
# Predicted as track when it was numTracks
# Predicted as - when it was url
# Predicted as - when it was birthPlace
# Predicted as - when it was birthDate
# Predicted as - when it was givenName
# Predicted as - when it was familyName
# Predicted as - when it was familyName
# Predicted as - when it was givenName
# Predicted as - when it was familyName
# Predicted as - when it was deathDate
# Predicted as - when it was givenName
# Predicted as - when it was familyName
# Predicted as - when it was birthDate
# Predicted as - when it was birthPlace
# Predicted as - when it was givenName
# Predicted as - when it was familyName
# Predicted as - when it was birthDate
# Predicted as - when it was nationality
# Predicted as - when it was deathDate
# Predicted as - when it was alumniOf
# Predicted as - when it was birthPlace
# Predicted as - when it was birthDate
# Predicted as - when it was jobTitle
# Predicted as - when it was alumniOf
# Predicted as - when it was honorificSuffix
# Predicted as - when it was measurements
# Predicted as - when it was givenName
# Predicted as - when it was birthDate
# Predicted as - when it was familyName
# Predicted as - when it was alumniOf
# Predicted as - when it was honorificSuffix
# Predicted as - when it was alumniOf
# Predicted as location when it was birthPlace
# Predicted as - when it was jobTitle
# Predicted as - when it was jobTitle
# Predicted as - when it was alumniOf
# Predicted as - when it was honorificSuffix
# Predicted as - when it was alumniOf
# Predicted as - when it was measurements
# Predicted as actor when it was birthPlace
# Predicted as - when it was birthDate
# Predicted as address when it was birthPlace
# Predicted as - when it was alumniOf
# Predicted as - when it was color
# Predicted as - when it was measurements
# Predicted as - when it was measurements
# Predicted as - when it was measurements
# Predicted as - when it was itemCondition
# Predicted as - when it was releaseDate
# Predicted as - when it was unitCode
# Predicted as - when it was releaseDate
# Predicted as - when it was bestRating
# Predicted as - when it was worstRating
# Predicted as - when it was ratingValue
# Predicted as - when it was color
# Predicted as - when it was model
# Predicted as - when it was productID
# Predicted as - when it was itemCondition
# Predicted as gtin when it was productID
# Predicted as - when it was itemCondition
# Predicted as - when it was releaseDate
# Predicted as - when it was measurements
# Predicted as - when it was measurements
# Predicted as - when it was measurements
# Predicted as model when it was productID
# Predicted as - when it was category
# Predicted as - when it was itemCondition
# Predicted as - when it was brand
# Predicted as - when it was unitText
# Predicted as - when it was description
# Predicted as - when it was measurements
# Predicted as category when it was description
# Predicted as - when it was image
# Predicted as - when it was productID
# Predicted as category when it was unitText
# Predicted as url when it was image
# Predicted as - when it was unitText
# Predicted as - when it was material
# Predicted as - when it was brand
# Predicted as - when it was suitableForDiet
# Predicted as - when it was description
# Predicted as - when it was prepTime
# Predicted as - when it was cookTime
# Predicted as - when it was nutrition
# Predicted as - when it was nutrition
# Predicted as category when it was nutrition
# Predicted as - when it was nutrition
# Predicted as - when it was nutrition
# Predicted as - when it was nutrition
# Predicted as - when it was recipeIngredient
# Predicted as - when it was totalTime
# Predicted as - when it was prepTime
# Predicted as - when it was cookTime
# Predicted as - when it was totalTime
# Predicted as - when it was recipeIngredient
# Predicted as category when it was recipeCuisine
# Predicted as - when it was suitableForDiet
# Predicted as - when it was ratingValue
# Predicted as category when it was recipeCategory
# Predicted as - when it was totalTime
# Predicted as category when it was recipeCuisine
# Predicted as - when it was cookingMethod
# Predicted as - when it was servingSize
# Predicted as - when it was review
# Predicted as - when it was recipeIngredient
# Predicted as category when it was recipeCategory
# Predicted as category when it was cookingMethod
# Predicted as - when it was recipeCuisine
# Predicted as category when it was review
# Predicted as - when it was recipeIngredient
# Predicted as - when it was recipeInstructions
# Predicted as category when it was review
# Predicted as - when it was totalTime
# Predicted as category when it was recipeIngredient
# Predicted as category when it was recipeCuisine
# Predicted as - when it was cookingMethod
# Predicted as category when it was recipeCategory
# Predicted as - when it was bestRating
# Predicted as - when it was ratingValue
# Predicted as - when it was recipeInstructions
# Predicted as - when it was suitableForDiet
# Predicted as - when it was servingSize
# Predicted as - when it was cookingMethod
# Predicted as - when it was recipeIngredient
# Predicted as totalTime when it was cookTime
# Predicted as - when it was recipeCategory
# Predicted as - when it was recipeCuisine
# Predicted as - when it was recipeInstructions
# Predicted as - when it was prepTime
# Predicted as - when it was cookingMethod
# Predicted as category when it was recipeCuisine
# Predicted as - when it was servingSize
# Predicted as - when it was cookingMethod
# Predicted as - when it was cookTime
# Predicted as category when it was recipeCategory
# Predicted as - when it was cookTime
# Predicted as - when it was cookingMethod
# Predicted as category when it was ratingValue
# Predicted as - when it was servingSize
# Predicted as - when it was suitableForDiet
# Predicted as - when it was servingSize
# Predicted as - when it was recipeIngredient
# Predicted as - when it was cookTime
# Predicted as - when it was recipeCategory
# Predicted as - when it was totalTime
# Predicted as - when it was recipeCuisine
# Predicted as - when it was recipeInstructions
# Predicted as - when it was prepTime
# Predicted as - when it was suitableForDiet
# Predicted as category when it was description
# Predicted as category when it was recipeCategory
# Predicted as category when it was servingSize
# Predicted as - when it was cookTime
# Predicted as - when it was prepTime
# Predicted as - when it was suitableForDiet
# Predicted as - when it was openingHours
# Predicted as - when it was servesCuisine
# Predicted as - when it was validThrough
# Predicted as - when it was startDate
# Predicted as - when it was description
# Predicted as - when it was endDate
# Predicted as - when it was validFrom
# Predicted as - when it was price
# Predicted as - when it was telephone
# Predicted as - when it was organizer
# Predicted as category when it was priceCurrency
# Predicted as - when it was startDate
# Predicted as - when it was endDate
# Predicted as location when it was organizer
# Predicted as - when it was eventStatus
# Predicted as - when it was validFrom
# Predicted as - when it was validFrom
# Predicted as - when it was startDate
# Predicted as address when it was location
# Predicted as - when it was endDate
# Predicted as - when it was priceCurrency
# Predicted as - when it was price
# Predicted as - when it was validThrough
# Predicted as location when it was organizer
# Predicted as - when it was validFrom
# Predicted as - when it was validThrough
# Predicted as - when it was startDate
# Predicted as category when it was description
# Predicted as - when it was endDate
# Predicted as - when it was eventAttendanceMode
# Predicted as - when it was validFrom
# Predicted as - when it was eventStatus
# Predicted as category when it was price
# Predicted as category when it was priceCurrency
# Predicted as - when it was validFrom
# Predicted as - when it was validThrough
# Predicted as - when it was eventStatus
# Predicted as - when it was eventAttendanceMode
# Predicted as - when it was endDate
# Predicted as - when it was organizer
# Predicted as location when it was email
# Predicted as - when it was startDate
# Predicted as - when it was endDate
# Predicted as - when it was validFrom
# Predicted as - when it was validThrough
# Predicted as - when it was eventStatus
# Predicted as - when it was eventAttendanceMode
# Predicted as - when it was validFrom
# Predicted as - when it was validThrough
# Predicted as url when it was eventStatus
# Predicted as - when it was eventAttendanceMode
# Predicted as - when it was validFrom
# Predicted as - when it was validThrough
# Predicted as - when it was eventAttendanceMode
# Predicted as - when it was eventStatus
# Predicted as - when it was validFrom
# Predicted as - when it was eventAttendanceMode
# Predicted as - when it was eventStatus
# Predicted as - when it was validFrom
# Predicted as - when it was organizer
# Predicted as address when it was addressRegion
# Predicted as address when it was addressCountry
# Predicted as address when it was addressLocality
# Predicted as address when it was streetAddress
# Predicted as - when it was priceRange
# Predicted as - when it was review
# Predicted as - when it was faxNumber
# Predicted as address when it was streetAddress
# Predicted as - when it was priceRange
# Predicted as location when it was description
# Predicted as location when it was addressLocality
# Predicted as location when it was addressCountry
# Predicted as manufacturer when it was priceRange
# Predicted as telephone when it was faxNumber
# Predicted as address when it was streetAddress
# Predicted as address when it was addressRegion
# Predicted as location when it was addressLocality
# Predicted as - when it was postalCode
# Predicted as telephone when it was faxNumber
# Predicted as - when it was faxNumber
# Predicted as - when it was telephone
# Predicted as - when it was addressLocality
# Predicted as - when it was addressRegion
# Predicted as address when it was streetAddress
# Predicted as - when it was postalCode
# Predicted as - when it was faxNumber
# Predicted as - when it was telephone
# Predicted as - when it was postalCode
# Predicted as - when it was addressRegion
# Predicted as address when it was streetAddress
# Predicted as address when it was addressLocality
# Predicted as telephone when it was faxNumber
# Predicted as location when it was addressRegion
# Predicted as address when it was addressLocality
# Predicted as - when it was addressCountry
# Predicted as location when it was addressCountry
# Predicted as telephone when it was faxNumber
# Predicted as - when it was telephone
# Predicted as address when it was addressCountry
# Predicted as address when it was addressRegion
# Predicted as address when it was streetAddress
# Predicted as - when it was postalCode
# Predicted as - when it was addressLocality
# Predicted as telephone when it was faxNumber
# Predicted as - when it was telephone
# Predicted as - when it was priceRange
# Predicted as - when it was dateCreated
# Predicted as - when it was duration
# Predicted as - when it was actor
# Predicted as - when it was duration
# Predicted as - when it was dateCreated
# Predicted as - when it was contentRating
# Predicted as - when it was ratingValue
# Predicted as - when it was worstRating
# Predicted as - when it was bestRating
# Predicted as - when it was duration
# Predicted as - when it was dateCreated
# Predicted as - when it was contentRating
# Predicted as - when it was bestRating
# Predicted as - when it was ratingValue
# Predicted as - when it was worstRating
# Predicted as - when it was actor
# Predicted as - when it was duration
# Predicted as category when it was worstRating
# Predicted as - when it was dateCreated
# Predicted as - when it was description
# Predicted as - when it was contentRating
# Predicted as category when it was bestRating
# Predicted as - when it was actor
# Predicted as review when it was ratingValue
# Predicted as - when it was duration
# Predicted as - when it was ratingValue
# Predicted as - when it was worstRating
# Predicted as - when it was bestRating
# Predicted as - when it was dateCreated
# Predicted as - when it was description
# Predicted as - when it was contentRating
# Predicted as - when it was dateCreated
# Predicted as performer when it was actor
# Predicted as - when it was birthDate
# Predicted as - when it was nationality
# Predicted as - when it was birthDate
# Predicted as - when it was jobTitle
# Predicted as - when it was birthDate
# Predicted as - when it was description
# Predicted as actor when it was jobTitle
# Predicted as - when it was birthDate
# Predicted as - when it was jobTitle
# Predicted as - when it was jobTitle
# Predicted as - when it was faxNumber
# Predicted as - when it was image
# Predicted as - when it was jobTitle
# Predicted as - when it was telephone
# Predicted as - when it was description
# Predicted as - when it was birthDate
# Predicted as - when it was image
# Predicted as - when it was releaseDate
# Predicted as - when it was itemCondition
# Predicted as - when it was category
# Predicted as - when it was releaseDate
# Predicted as - when it was itemCondition
# Predicted as - when it was category
# Predicted as - when it was releaseDate
# Predicted as - when it was review
# Predicted as - when it was category
# Predicted as - when it was releaseDate
# Predicted as - when it was releaseDate
# Predicted as - when it was itemCondition
# Predicted as - when it was category
# Predicted as - when it was releaseDate
# Predicted as - when it was category
# Predicted as - when it was releaseDate
# Predicted as - when it was category
# Predicted as - when it was itemCondition
# Predicted as - when it was weight
# Predicted as category when it was weight
# Predicted as - when it was itemCondition
# Predicted as manufacturer when it was releaseDate
# Predicted as brand when it was review
# Predicted as - when it was datePublished
# Predicted as category when it was text
# Predicted as category when it was headline
# Predicted as - when it was copyrightYear
# Predicted as - when it was startDate
# Predicted as - when it was endDate
# Predicted as - when it was organizer
# Predicted as - when it was startDate
# Predicted as - when it was endDate
# Predicted as - when it was startDate
# Predicted as - when it was endDate
# Predicted as brand when it was location
# Predicted as brand when it was organizer
# Predicted as - when it was performer
# Predicted as - when it was eventStatus
# Predicted as - when it was eventAttendanceMode
# Predicted as - when it was price
# Predicted as - when it was startDate
# Predicted as organizer when it was description
# Predicted as - when it was endDate
# Predicted as - when it was location
# Predicted as category when it was priceCurrency
# Predicted as - when it was availability
# Predicted as - when it was startDate
# Predicted as - when it was endDate
# Predicted as - when it was category
# Predicted as - when it was organizer
# Predicted as - when it was endDate
# Predicted as - when it was eventAttendanceMode
# Predicted as - when it was eventStatus
# Predicted as - when it was startDate
# Predicted as - when it was startDate
# Predicted as - when it was endDate
# Predicted as location when it was organizer
# Predicted as - when it was email
# Predicted as location when it was checkInTime
# Predicted as address when it was addressLocality
# Predicted as - when it was checkoutTime
# Predicted as address when it was streetAddress
# Predicted as - when it was postalCode
# Predicted as address when it was addressRegion
# Predicted as - when it was ratingValue
# Predicted as location when it was longitude
# Predicted as location when it was latitude
# Predicted as location when it was description
# Predicted as - when it was checkInTime
# Predicted as location when it was latitude
# Predicted as location when it was longitude
# Predicted as - when it was checkoutTime
# Predicted as - when it was priceRange
# Predicted as location when it was description
# Predicted as - when it was amenityFeature
# Predicted as location when it was addressCountry
# Predicted as - when it was postalCode
# Predicted as location when it was addressLocality
# Predicted as address when it was streetAddress
# Predicted as - when it was addressRegion
# Predicted as - when it was priceRange
# Predicted as location when it was addressLocality
# Predicted as - when it was telephone
# Predicted as address when it was streetAddress
# Predicted as location when it was addressCountry
# Predicted as location when it was latitude
# Predicted as location when it was availableLanguage
# Predicted as - when it was ratingValue
# Predicted as telephone when it was faxNumber
# Predicted as location when it was url
# Predicted as - when it was paymentAccepted
# Predicted as priceRange when it was currenciesAccepted
# Predicted as - when it was postalCode
# Predicted as address when it was addressCountry
# Predicted as - when it was addressLocality
# Predicted as address when it was streetAddress
# Predicted as location when it was description
# Predicted as location when it was worstRating
# Predicted as - when it was ratingValue
# Predicted as location when it was bestRating
# Predicted as location when it was latitude
# Predicted as - when it was amenityFeature
# Predicted as - when it was longitude
# Predicted as telephone when it was faxNumber
# Predicted as - when it was postalCode
# Predicted as address when it was streetAddress
# Predicted as - when it was addressRegion
# Predicted as - when it was ratingValue
# Predicted as address when it was addressLocality
# Predicted as location when it was addressCountry
# Predicted as - when it was dayOfWeek
# Predicted as - when it was closes
# Predicted as - when it was opens
# Predicted as manufacturer when it was addressRegion
# Predicted as - when it was priceRange
# Predicted as - when it was closes
# Predicted as - when it was worstRating
# Predicted as - when it was dayOfWeek
# Predicted as - when it was opens
# Predicted as address when it was telephone
# Predicted as - when it was opens
# Predicted as - when it was dayOfWeek
# Predicted as address when it was closes
# Predicted as address when it was addressRegion
# Predicted as - when it was priceRange
# Predicted as - when it was closes
# Predicted as - when it was opens
# Predicted as - when it was dayOfWeek
# Predicted as - when it was duration
# Predicted as - when it was datePublished
# Predicted as - when it was contentRating
# Predicted as - when it was ratingValue
# Predicted as - when it was bestRating
# Predicted as - when it was actor
# Predicted as - when it was worstRating
# Predicted as - when it was datePublished
# Predicted as performer when it was inLanguage
# Predicted as performer when it was director
# Predicted as - when it was productionCompany
# Predicted as - when it was bestRating
# Predicted as - when it was ratingValue
# Predicted as - when it was duration
# Predicted as - when it was datePublished
# Predicted as - when it was contentRating
# Predicted as - when it was bestRating
# Predicted as review when it was ratingValue
# Predicted as - when it was actor
# Predicted as category when it was worstRating
# Predicted as - when it was duration
# Predicted as - when it was datePublished
# Predicted as itemCondition when it was contentRating
# Predicted as - when it was bestRating
# Predicted as - when it was ratingValue
# Predicted as track when it was worstRating
# Predicted as - when it was actor
# Predicted as - when it was givenName
# Predicted as - when it was familyName
# Predicted as - when it was birthDate
# Predicted as - when it was deathDate
# Predicted as - when it was jobTitle
# Predicted as - when it was birthDate
# Predicted as - when it was deathDate
# Predicted as - when it was givenName
# Predicted as - when it was familyName
# Predicted as - when it was birthDate
# Predicted as - when it was deathDate
# Predicted as - when it was description
# Predicted as - when it was birthDate
# Predicted as - when it was givenName
# Predicted as - when it was familyName
# Predicted as - when it was birthPlace
# Predicted as - when it was nationality
# Predicted as - when it was birthDate
# Predicted as - when it was nationality
# Predicted as - when it was jobTitle
# Predicted as - when it was familyName
# Predicted as - when it was givenName
# Predicted as - when it was birthDate
# Predicted as - when it was jobTitle
# Predicted as - when it was familyName
# Predicted as - when it was givenName
# Predicted as performer when it was birthDate
# Predicted as - when it was deathDate
# Predicted as - when it was description
# Predicted as - when it was birthDate
# Predicted as - when it was deathDate
# Predicted as - when it was description
# Predicted as - when it was birthDate
# Predicted as - when it was deathDate
# Predicted as - when it was description
# Predicted as - when it was deathDate
# Predicted as - when it was birthDate
# Predicted as - when it was deathDate
# Predicted as - when it was givenName
# Predicted as - when it was familyName
# Predicted as givenName when it was birthDate
# Predicted as - when it was deathDate
# Predicted as - when it was givenName
# Predicted as - when it was familyName
# Predicted as - when it was birthDate
# Predicted as - when it was nationality
# Predicted as - when it was givenName
# Predicted as - when it was familyName
# Predicted as - when it was measurements
# Predicted as - when it was nationality
# Predicted as - when it was birthDate
# Predicted as location when it was birthPlace
# Predicted as - when it was measurements
# Predicted as - when it was nationality
# Predicted as location when it was birthPlace
# Predicted as - when it was releaseDate
# Predicted as - when it was color
# Predicted as - when it was category
# Predicted as - when it was itemCondition
# Predicted as - when it was releaseDate
# Predicted as - when it was releaseDate
# Predicted as - when it was unitCode
# Predicted as - when it was releaseDate
# Predicted as - when it was unitCode
# Predicted as - when it was weight
# Predicted as - when it was gtin
# Predicted as gtin when it was productID
# Predicted as priceRange when it was price
# Predicted as category when it was servingSize
# Predicted as - when it was nutrition
# Predicted as category when it was recipeCuisine
# Predicted as - when it was recipeIngredient
# Predicted as category when it was recipeCategory
# Predicted as - when it was recipeInstructions
# Predicted as category when it was nutrition
# Predicted as - when it was nutrition
# Predicted as - when it was prepTime
# Predicted as - when it was servingSize
# Predicted as category when it was nutrition
# Predicted as category when it was nutrition
# Predicted as - when it was nutrition
# Predicted as - when it was nutrition
# Predicted as - when it was nutrition
# Predicted as - when it was nutrition
# Predicted as - when it was prepTime
# Predicted as - when it was nutrition
# Predicted as - when it was nutrition
# Predicted as - when it was recipeIngredient
# Predicted as - when it was cookTime
# Predicted as category when it was recipeCategory
# Predicted as - when it was totalTime
# Predicted as category when it was recipeCuisine
# Predicted as - when it was recipeInstructions
# Predicted as - when it was nutrition
# Predicted as - when it was nutrition
# Predicted as - when it was nutrition
# Predicted as - when it was nutrition
# Predicted as - when it was cookingMethod
# Predicted as - when it was cookTime
# Predicted as - when it was recipeCategory
# Predicted as - when it was recipeCuisine
# Predicted as - when it was nutrition
# Predicted as - when it was servingSize
# Predicted as - when it was servingSize
# Predicted as - when it was recipeIngredient
# Predicted as - when it was cookTime
# Predicted as - when it was recipeCategory
# Predicted as - when it was totalTime
# Predicted as - when it was recipeInstructions
# Predicted as - when it was nutrition
# Predicted as - when it was prepTime
# Predicted as - when it was nutrition
# Predicted as category when it was servingSize
# Predicted as - when it was recipeIngredient
# Predicted as - when it was cookTime
# Predicted as category when it was recipeCategory
# Predicted as - when it was totalTime
# Predicted as - when it was recipeCuisine
# Predicted as - when it was recipeInstructions
# Predicted as - when it was prepTime
# Predicted as address when it was addressLocality
# Predicted as - when it was worstRating
# Predicted as - when it was bestRating
# Predicted as - when it was ratingValue
# Predicted as - when it was openingHours
# Predicted as location when it was longitude
# Predicted as location when it was latitude
# Predicted as - when it was worstRating
# Predicted as - when it was bestRating
# Predicted as category when it was inLanguage
# Predicted as - when it was ratingValue
# Predicted as - when it was bestRating
# Predicted as category when it was worstRating
# Predicted as - when it was datePublished
# Predicted as description when it was review
# Predicted as - when it was genre
# Predicted as priceRange when it was priceCurrency
# Predicted as category when it was price
# Predicted as category when it was priceCurrency
# Predicted as - when it was bestRating
# Predicted as - when it was worstRating
# Predicted as - when it was datePublished
# Predicted as - when it was worstRating
# Predicted as - when it was bestRating
# Predicted as category when it was review
# Predicted as - when it was inLanguage
# Predicted as category when it was bookFormat
# Predicted as - when it was numberOfPages
# Predicted as - when it was inLanguage
# Predicted as category when it was headline
# Predicted as location when it was longitude
# Predicted as address when it was addressLocality
# Predicted as category when it was image
# Predicted as - when it was givenName
# Predicted as - when it was familyName
# Predicted as - when it was category
# Predicted as - when it was productID
# Predicted as weight when it was servingSize
# Predicted as - when it was cookTime
# Predicted as - when it was cookTime
# Predicted as author when it was url
# Predicted as - when it was jobTitle
# Predicted as - when it was telephone
# Predicted as - when it was address
# Predicted as - when it was eventAttendanceMode
# Predicted as - when it was organizer
# Predicted as - when it was eventStatus
# Predicted as location when it was review
# Predicted as address when it was description
# Predicted as manufacturer when it was brand
# Predicted as - when it was openingHours
# Predicted as - when it was openingHours
# Predicted as - when it was dayOfWeek
# Predicted as location when it was dayOfWeek
# Predicted as - when it was addressLocality
# Predicted as address when it was streetAddress
# Predicted as - when it was actor
# Predicted as - when it was actor
# Predicted as - when it was byArtist
# Predicted as - when it was duration
# Predicted as - when it was track
# Predicted as - when it was byArtist
# Predicted as - when it was bestRating
# Predicted as - when it was priceCurrency
# Predicted as - when it was price
# Predicted as - when it was description
# Predicted as - when it was bookFormat
# Predicted as - when it was bookFormat
# Predicted as - when it was publisher
# Predicted as - when it was price
# Predicted as category when it was priceCurrency
# Predicted as - when it was availability
# Predicted as - when it was priceCurrency
# Predicted as - when it was datePublished
# Predicted as - when it was author
# Predicted as priceRange when it was price
# Predicted as - when it was priceCurrency
# Predicted as category when it was availability
# Predicted as - when it was price
# Predicted as - when it was ratingValue
# Predicted as - when it was datePublished
# Predicted as - when it was inLanguage
# Predicted as - when it was bookFormat
# Predicted as - when it was image
# Predicted as releaseDate when it was datePublished
# Predicted as - when it was priceCurrency
# Predicted as category when it was bookFormat
# Predicted as - when it was numberOfPages
# Predicted as category when it was price
# Predicted as - when it was datePublished
# Predicted as category when it was availability
# Predicted as - when it was itemCondition
# Predicted as - when it was datePublished
# Predicted as - when it was priceCurrency
# Predicted as - when it was author
# Predicted as - when it was price
# Predicted as - when it was availability
# Predicted as - when it was inLanguage
# Predicted as - when it was bookFormat
# Predicted as - when it was numberOfPages
# Predicted as category when it was genre
# Predicted as - when it was inLanguage
# Predicted as - when it was bookFormat
# Predicted as - when it was datePublished
# Predicted as category when it was numberOfPages
# Predicted as gtin when it was isbn
# Predicted as - when it was ratingValue
# Predicted as - when it was datePublished
# Predicted as - when it was url
# Predicted as category when it was genre
# Predicted as - when it was datePublished
# Predicted as - when it was numberOfPages
# Predicted as - when it was author
# Predicted as category when it was publisher
# Predicted as - when it was datePublished
# Predicted as category when it was description
# Predicted as - when it was author
# Predicted as - when it was datePublished
# Predicted as category when it was description
# Predicted as category when it was url
# Predicted as category when it was genre
# Predicted as - when it was startDate
# Predicted as - when it was endDate
# Predicted as - when it was inLanguage
# Predicted as - when it was location
# Predicted as - when it was startDate
# Predicted as - when it was endDate
# Predicted as category when it was eventStatus
# Predicted as - when it was eventAttendanceMode
# Predicted as - when it was priceRange
# Predicted as - when it was telephone
# Predicted as address when it was streetAddress
# Predicted as - when it was addressLocality
# Predicted as - when it was addressCountry
# Predicted as location when it was addressLocality
# Predicted as - when it was postalCode
# Predicted as category when it was image
# Predicted as manufacturer when it was priceRange
# Predicted as - when it was priceRange
# Predicted as - when it was description
# Predicted as - when it was ratingValue
# Predicted as - when it was worstRating
# Predicted as - when it was bestRating
# Predicted as - when it was datePublished
# Predicted as - when it was worstRating
# Predicted as - when it was bestRating
# Predicted as - when it was actor
# Predicted as - when it was dateCreated
# Predicted as genre when it was description
# Predicted as - when it was datePublished
# Predicted as - when it was ratingValue
# Predicted as - when it was worstRating
# Predicted as - when it was bestRating
# Predicted as - when it was contentRating
# Predicted as - when it was dateCreated
# Predicted as - when it was actor
# Predicted as - when it was dateCreated
# Predicted as review when it was description
# Predicted as - when it was actor
# Predicted as performer when it was actor
# Predicted as - when it was duration
# Predicted as - when it was genre
# Predicted as - when it was jobTitle
# Predicted as - when it was nationality
# Predicted as - when it was nationality
# Predicted as - when it was description
# Predicted as - when it was jobTitle
# Predicted as - when it was jobTitle
# Predicted as performer when it was image
# Predicted as - when it was description
# Predicted as - when it was jobTitle
# Predicted as - when it was jobTitle
# Predicted as - when it was description
# Predicted as - when it was jobTitle
# Predicted as - when it was postalCode
# Predicted as - when it was addressLocality
# Predicted as - when it was itemCondition
# Predicted as category when it was url
# Predicted as - when it was datePublished
# Predicted as priceRange when it was price
# Predicted as - when it was inLanguage
# Predicted as - when it was url
# Predicted as - when it was price
# Predicted as - when it was priceCurrency
# Predicted as - when it was numberOfPages
# Predicted as - when it was bookFormat
# Predicted as - when it was author
# Predicted as - when it was copyrightYear
# Predicted as category when it was numberOfPages
# Predicted as - when it was inLanguage
# Predicted as category when it was numberOfPages
# Predicted as - when it was bookFormat
# Predicted as - when it was bookEdition
# Predicted as - when it was author
# Predicted as - when it was copyrightYear
# Predicted as - when it was numberOfPages
# Predicted as - when it was datePublished
# Predicted as gtin when it was isbn
# Predicted as author when it was bookFormat
# Predicted as - when it was numberOfPages
# Predicted as publisher when it was url
# Predicted as - when it was author
# Predicted as gtin when it was isbn
# Predicted as - when it was bookFormat
# Predicted as - when it was numberOfPages
# Predicted as - when it was inLanguage
# Predicted as - when it was ratingValue
# Predicted as - when it was datePublished
# Predicted as - when it was inLanguage
# Predicted as - when it was bookFormat
# Predicted as - when it was numberOfPages
# Predicted as - when it was bookEdition
# Predicted as - when it was priceCurrency
# Predicted as - when it was bookEdition
# Predicted as - when it was availability
# Predicted as - when it was price
# Predicted as - when it was datePublished
# Predicted as - when it was author
# Predicted as - when it was numberOfPages
# Predicted as - when it was bookFormat
# Predicted as - when it was bestRating
# Predicted as - when it was worstRating
# Predicted as - when it was priceCurrency
# Predicted as - when it was numberOfPages
# Predicted as category when it was price
# Predicted as - when it was priceCurrency
# Predicted as publisher when it was author
# Predicted as - when it was availability
# Predicted as category when it was datePublished
# Predicted as category when it was bookEdition
# Predicted as category when it was description
# Predicted as category when it was author
# Predicted as category when it was publisher
# Predicted as - when it was author
# Predicted as description when it was headline
# Predicted as - when it was text
# Predicted as location when it was author
# Predicted as - when it was headline
# Predicted as - when it was text
# Predicted as location when it was datePublished
# Predicted as publisher when it was author
# Predicted as category when it was headline
# Predicted as review when it was text
# Predicted as - when it was datePublished
# Predicted as - when it was description
# Predicted as - when it was text
# Predicted as - when it was headline
# Predicted as - when it was organizer
# Predicted as category when it was location
# Predicted as category when it was email
# Predicted as - when it was eventStatus
# Predicted as - when it was eventAttendanceMode
# Predicted as location when it was addressLocality
# Predicted as - when it was priceRange
# Predicted as - when it was addressCountry
# Predicted as address when it was streetAddress
# Predicted as location when it was addressLocality
# Predicted as location when it was addressCountry
# Predicted as address when it was addressRegion
# Predicted as location when it was latitude
# Predicted as address when it was addressLocality
# Predicted as category when it was description
# Predicted as - when it was openingHours
# Predicted as priceRange when it was currenciesAccepted
# Predicted as address when it was streetAddress
# Predicted as location when it was latitude
# Predicted as location when it was longitude
# Predicted as location when it was addressCountry
# Predicted as address when it was streetAddress
# Predicted as - when it was paymentAccepted
# Predicted as location when it was addressCountry
# Predicted as - when it was postalCode
# Predicted as - when it was addressLocality
# Predicted as - when it was worstRating
# Predicted as - when it was amenityFeature
# Predicted as - when it was bestRating
# Predicted as - when it was faxNumber
# Predicted as location when it was description
# Predicted as - when it was paymentAccepted
# Predicted as - when it was bestRating
# Predicted as - when it was ratingValue
# Predicted as url when it was image
# Predicted as - when it was paymentAccepted
# Predicted as - when it was currenciesAccepted
# Predicted as - when it was worstRating
# Predicted as - when it was ratingValue
# Predicted as - when it was bestRating
# Predicted as - when it was amenityFeature
# Predicted as - when it was openingHours
# Predicted as - when it was dayOfWeek
# Predicted as - when it was closes
# Predicted as - when it was opens
# Predicted as - when it was addressRegion
# Predicted as - when it was paymentAccepted
# Predicted as - when it was currenciesAccepted
# Predicted as availability when it was openingHours
# Predicted as - when it was opens
# Predicted as - when it was closes
# Predicted as availability when it was dayOfWeek
# Predicted as - when it was closes
# Predicted as - when it was dayOfWeek
# Predicted as - when it was opens
# Predicted as - when it was faxNumber
# Predicted as - when it was openingHours
# Predicted as - when it was paymentAccepted
# Predicted as - when it was currenciesAccepted
# Predicted as - when it was ratingValue
# Predicted as - when it was worstRating
# Predicted as - when it was bestRating
# Predicted as category when it was description
# Predicted as - when it was datePublished
# Predicted as performer when it was actor
# Predicted as - when it was duration
# Predicted as - when it was datePublished
# Predicted as - when it was bestRating
# Predicted as - when it was worstRating
# Predicted as performer when it was actor
# Predicted as - when it was datePublished
# Predicted as performer when it was actor
# Predicted as - when it was datePublished
# ...
# Predicted as - when it was email
# Predicted as - when it was telephone
# Predicted as opens when it was startDate
# Predicted as opens when it was endDate
# Predicted as address when it was location
# Predicted as organizer when it was performer
# Predicted as priceRange when it was priceCurrency
# Predicted as priceRange when it was price
# Predicted as - when it was startDate
# Predicted as - when it was performer
# Predicted as organizer when it was location
# Predicted as - when it was endDate
# Predicted as priceRange when it was priceCurrency
# Predicted as location when it was availability
# Predicted as - when it was startDate
# Predicted as - when it was description
# Predicted as - when it was endDate
# Predicted as category when it was performer
# Predicted as - when it was price
# Predicted as - when it was priceCurrency
# Predicted as - when it was startDate
# Predicted as - when it was endDate
# Predicted as - when it was performer
# Predicted as priceRange when it was priceCurrency
# Predicted as - when it was price
# Predicted as - when it was startDate
# Predicted as - when it was endDate
# Predicted as - when it was performer
# Predicted as - when it was location
# Predicted as - when it was eventStatus
# Predicted as - when it was eventAttendanceMode
# Predicted as - when it was checkInTime
# Predicted as - when it was checkoutTime
# Predicted as priceRange when it was currenciesAccepted
# Predicted as - when it was telephone
# Predicted as - when it was description
# Predicted as - when it was amenityFeature
# Predicted as address when it was addressCountry
# Predicted as location when it was addressLocality
# Predicted as address when it was streetAddress
# Predicted as - when it was postalCode
# Predicted as - when it was addressRegion
# Predicted as priceRange when it was ratingValue
# Predicted as priceRange when it was bestRating
# Predicted as - when it was checkoutTime
# Predicted as - when it was checkInTime
# Predicted as location when it was addressCountry
# Predicted as - when it was availableLanguage
# Predicted as - when it was checkInTime
# Predicted as - when it was checkoutTime
# Predicted as address when it was addressCountry
# Predicted as address when it was streetAddress
# Predicted as - when it was postalCode
# Predicted as - when it was bestRating
# Predicted as - when it was ratingValue
# Predicted as location when it was longitude
# Predicted as location when it was latitude
# Predicted as - when it was addressLocality
# Predicted as location when it was review
# Predicted as - when it was checkInTime
# Predicted as - when it was addressLocality
# Predicted as location when it was addressCountry
# Predicted as - when it was checkoutTime
# Predicted as address when it was streetAddress
# Predicted as - when it was postalCode
# Predicted as - when it was ratingValue
# Predicted as - when it was bestRating
# Predicted as - when it was latitude
# Predicted as - when it was longitude
# Predicted as location when it was amenityFeature
# Predicted as - when it was worstRating
# Predicted as - when it was datePosted
# Predicted as - when it was jobTitle
# Predicted as - when it was description
# Predicted as - when it was url
# Predicted as - when it was employmentType
# Predicted as - when it was datePosted
# Predicted as - when it was jobTitle
# Predicted as - when it was url
# Predicted as - when it was hiringOrganization
# Predicted as - when it was datePosted
# Predicted as - when it was jobTitle
# Predicted as - when it was hiringOrganization
# Predicted as - when it was employmentType
# Predicted as - when it was jobTitle
# Predicted as - when it was datePosted
# Predicted as jobTitle when it was hiringOrganization
# Predicted as - when it was employmentType
# Predicted as location when it was address
# Predicted as - when it was hiringOrganization
# Predicted as - when it was datePosted
# Predicted as - when it was jobTitle
# Predicted as - when it was employmentType
# Predicted as - when it was datePosted
# Predicted as - when it was jobTitle
# Predicted as - when it was employmentType
# Predicted as - when it was hiringOrganization
# Predicted as - when it was datePosted
# Predicted as category when it was jobTitle
# Predicted as - when it was employmentType
# Predicted as category when it was hiringOrganization
# Predicted as - when it was datePosted
# Predicted as - when it was jobTitle
# Predicted as - when it was employmentType
# Predicted as organizer when it was hiringOrganization
# Predicted as - when it was datePosted
# Predicted as - when it was jobTitle
# Predicted as - when it was employmentType
# Predicted as manufacturer when it was hiringOrganization
# Predicted as - when it was jobTitle
# Predicted as - when it was datePosted
# Predicted as category when it was employmentType
# Predicted as - when it was hiringOrganization
# Predicted as - when it was jobTitle
# Predicted as - when it was datePosted
# Predicted as - when it was employmentType
# Predicted as - when it was jobTitle
# Predicted as - when it was datePosted
# Predicted as - when it was hiringOrganization
# Predicted as - when it was jobTitle
# Predicted as - when it was datePosted
# Predicted as - when it was employmentType
# Predicted as - when it was hiringOrganization
# Predicted as - when it was openingHours
# Predicted as manufacturer when it was paymentAccepted
# Predicted as - when it was closes
# Predicted as - when it was dayOfWeek
# Predicted as - when it was openingHours
# Predicted as location when it was opens
# Predicted as location when it was closes
# Predicted as location when it was dayOfWeek
# Predicted as location when it was addressRegion
# Predicted as - when it was paymentAccepted
# Predicted as category when it was currenciesAccepted
# Predicted as category when it was ratingValue
# Predicted as - when it was priceRange
# Predicted as - when it was addressLocality
# Predicted as address when it was streetAddress
# Predicted as - when it was postalCode
# Predicted as address when it was latitude
# Predicted as - when it was dayOfWeek
# Predicted as address when it was addressRegion
# Predicted as - when it was closes
# Predicted as - when it was telephone
# Predicted as - when it was currenciesAccepted
# Predicted as address when it was streetAddress
# Predicted as - when it was bestRating
# Predicted as category when it was worstRating
# Predicted as review when it was ratingValue
# Predicted as - when it was productionCompany
# Predicted as - when it was actor
# Predicted as - when it was productionCompany
# Predicted as - when it was bestRating
# Predicted as performer when it was actor
# Predicted as - when it was productionCompany
# Predicted as performer when it was actor
# Predicted as - when it was contentRating
# Predicted as - when it was datePublished
# Predicted as - when it was productionCompany
# Predicted as - when it was countryOfOrigin
# Predicted as performer when it was director
# Predicted as - when it was countryOfOrigin
# Predicted as - when it was duration
# Predicted as - when it was bestRating
# Predicted as performer when it was actor
# Predicted as - when it was countryOfOrigin
# Predicted as - when it was duration
# Predicted as - when it was image
# Predicted as - when it was inLanguage
# Predicted as - when it was duration
# Predicted as - when it was byArtist
# Predicted as - when it was track
# Predicted as - when it was genre
# Predicted as - when it was track
# Predicted as - when it was byArtist
# Predicted as - when it was duration
# Predicted as - when it was numTracks
# Predicted as - when it was numTracks
# Predicted as - when it was track
# Predicted as - when it was byArtist
# Predicted as - when it was numTracks
# Predicted as - when it was duration
# Predicted as - when it was byArtist
# Predicted as - when it was track
# Predicted as - when it was numTracks
# Predicted as - when it was duration
# Predicted as - when it was numTracks
# Predicted as - when it was byArtist
# Predicted as - when it was numTracks
# Predicted as - when it was byArtist
# Predicted as - when it was url
# Predicted as track when it was duration
# Predicted as - when it was track
# Predicted as - when it was numTracks
# Predicted as - when it was byArtist
# Predicted as - when it was duration
# Predicted as - when it was inAlbum
# Predicted as performer when it was byArtist
# Predicted as - when it was inAlbum
# Predicted as - when it was byArtist
# Predicted as - when it was duration
# Predicted as - when it was byArtist
# Predicted as performer when it was inAlbum
# Predicted as - when it was duration
# Predicted as - when it was inAlbum
# Predicted as - when it was byArtist
# Predicted as - when it was duration
# Predicted as - when it was byArtist
# Predicted as - when it was inAlbum
# Predicted as - when it was duration
# Predicted as - when it was inAlbum
# Predicted as - when it was byArtist
# Predicted as track when it was duration
# Predicted as - when it was inAlbum
# Predicted as performer when it was byArtist
# Predicted as - when it was duration
# Predicted as - when it was inAlbum
# Predicted as performer when it was byArtist
# Predicted as - when it was duration
# Predicted as - when it was byArtist
# Predicted as - when it was inAlbum
# Predicted as - when it was honorificSuffix
# Predicted as - when it was honorificSuffix
# Predicted as - when it was honorificSuffix
# Predicted as - when it was givenName
# Predicted as - when it was familyName
# Predicted as - when it was honorificSuffix
# Predicted as - when it was givenName
# Predicted as - when it was familyName
# Predicted as - when it was givenName
# Predicted as - when it was familyName
# Predicted as - when it was honorificSuffix
# Predicted as - when it was givenName
# Predicted as - when it was familyName
# Predicted as - when it was honorificSuffix
# Predicted as - when it was honorificSuffix
# Predicted as - when it was jobTitle
# Predicted as - when it was alumniOf
# Predicted as - when it was alumniOf
# Predicted as - when it was jobTitle
# Predicted as - when it was category
# Predicted as - when it was itemCondition
# Predicted as - when it was brand
# Predicted as gtin when it was model
# Predicted as - when it was color
# Predicted as category when it was unitCode
# Predicted as category when it was unitCode
# Predicted as category when it was unitCode
# Predicted as - when it was measurements
# Predicted as - when it was measurements
# Predicted as - when it was measurements
# Predicted as - when it was category
# Predicted as - when it was releaseDate
# Predicted as weight when it was unitCode
# Predicted as - when it was unitCode
# Predicted as - when it was unitCode
# Predicted as - when it was unitCode
# Predicted as - when it was weight
# Predicted as - when it was availableDeliveryMethod
# Predicted as - when it was productID
# Predicted as - when it was model
# Predicted as - when it was itemCondition
# Predicted as - when it was review
# Predicted as manufacturer when it was brand
# Predicted as - when it was category
# Predicted as - when it was productID
# Predicted as - when it was itemCondition
# Predicted as - when it was productID
# Predicted as priceRange when it was price
# Predicted as - when it was releaseDate
# Predicted as - when it was availableDeliveryMethod
# Predicted as - when it was productID
# Predicted as - when it was category
# Predicted as - when it was availableDeliveryMethod
# Predicted as - when it was paymentAccepted
# Predicted as - when it was productID
# Predicted as - when it was availableDeliveryMethod
# Predicted as - when it was productID
# Predicted as - when it was category
# Predicted as - when it was model
# Predicted as - when it was brand
# Predicted as weight when it was unitText
# Predicted as - when it was weight
# Predicted as - when it was availableDeliveryMethod
# Predicted as - when it was category
# Predicted as - when it was availableDeliveryMethod
# Predicted as - when it was productID
# Predicted as - when it was category
# Predicted as manufacturer when it was brand
# Predicted as - when it was productID
# Predicted as - when it was model
# Predicted as brand when it was manufacturer
# Predicted as - when it was material
# Predicted as - when it was gtin
# Predicted as - when it was gtin
# Predicted as - when it was availableDeliveryMethod
# Predicted as - when it was paymentAccepted
# Predicted as - when it was availableDeliveryMethod
# Predicted as - when it was category
# Predicted as - when it was productID
# Predicted as - when it was material
# Predicted as manufacturer when it was brand
# Predicted as - when it was availableDeliveryMethod
# Predicted as category when it was model
# Predicted as - when it was availableDeliveryMethod
# Predicted as - when it was paymentAccepted
# Predicted as url when it was image
# Predicted as - when it was unitText
# Predicted as - when it was material
# Predicted as - when it was productID
# Predicted as - when it was material
# Predicted as - when it was unitText
# Predicted as - when it was brand
# Predicted as - when it was unitText
# Predicted as - when it was recipeIngredient
# Predicted as - when it was recipeInstructions
# Predicted as - when it was cookingMethod
# Predicted as - when it was servingSize
# Predicted as - when it was suitableForDiet
# Predicted as category when it was recipeCuisine
# Predicted as - when it was servingSize
# Predicted as - when it was openingHours
# Predicted as - when it was servesCuisine
# Predicted as - when it was paymentAccepted
# Predicted as - when it was servesCuisine
# Predicted as location when it was openingHours
# Predicted as - when it was paymentAccepted
# Predicted as - when it was servesCuisine
# Predicted as - when it was openingHours
# Predicted as - when it was paymentAccepted
# Predicted as - when it was servesCuisine
# Predicted as location when it was openingHours
# Predicted as - when it was paymentAccepted
# Predicted as - when it was servesCuisine
# Predicted as - when it was openingHours
# Predicted as address when it was paymentAccepted
# Predicted as address when it was servesCuisine
# Predicted as - when it was openingHours
# Predicted as - when it was paymentAccepted
# Predicted as - when it was servesCuisine
# Predicted as - when it was openingHours
# Predicted as location when it was servesCuisine
# Predicted as - when it was startDate
# Predicted as - when it was awayTeam
# Predicted as - when it was homeTeam
# Predicted as - when it was startDate
# Predicted as - when it was endDate
# Predicted as - when it was eventStatus
# Predicted as - when it was awayTeam
# Predicted as - when it was homeTeam
# Predicted as - when it was homeTeam
# Predicted as - when it was awayTeam
# Predicted as - when it was startDate
# Predicted as - when it was location
# Predicted as - when it was eventAttendanceMode
# Predicted as - when it was homeTeam
# Predicted as - when it was awayTeam
# Predicted as - when it was startDate
# Predicted as - when it was awayTeam
# Predicted as - when it was homeTeam
# Predicted as - when it was homeTeam
# Predicted as - when it was awayTeam
# Predicted as - when it was startDate
# Predicted as - when it was endDate
# Predicted as - when it was image
# Predicted as - when it was category
# Predicted as - when it was startDate
# Predicted as - when it was awayTeam
# Predicted as - when it was endDate
# Predicted as - when it was homeTeam
# Predicted as - when it was startDate
# Predicted as - when it was awayTeam
# Predicted as - when it was homeTeam
# Predicted as - when it was episodeNumber
# Predicted as - when it was partOfSeries
# Predicted as - when it was episodeNumber
# Predicted as - when it was episodeNumber
# Predicted as - when it was partOfSeries
# Predicted as - when it was episodeNumber
# Predicted as - when it was description
# Predicted as - when it was partOfSeries
# Predicted as - when it was episodeNumber
# Predicted as category when it was description
# Predicted as - when it was partOfSeries
# Predicted as - when it was partOfSeries
# Predicted as - when it was url
# Predicted as - when it was partOfSeries
# Predicted as - when it was url
# Predicted as - when it was partOfSeries
# Predicted as - when it was episodeNumber
# Predicted as - when it was description
# Predicted as - when it was partOfSeries
# Predicted as - when it was partOfSeries
# Predicted as - when it was url
# Predicted as - when it was episodeNumber
# Predicted as text when it was episodeNumber
# Predicted as performer when it was description
# Predicted as - when it was partOfSeries
# Predicted as - when it was episodeNumber
# Predicted as - when it was description
# Predicted as - when it was partOfSeries
# 1927

# %% [markdown]
# ### Re-load previous preds files

# %%
with open(f'Predictions/{model_name}/s1-column-zero-shot.pkl', "rb") as f:
    preds = pickle.load(f)

# %%
preds
# Out:
# ['category',
#  'The type that best represents the relation between the two columns is "inLanguage".',
#  'The relation between the two columns is "itemCondition".',
#  'numberOfPages',
#  'The relation between the two columns seems to be related to the ISBN (International Standard Book Number) of the books. Therefore, the type that best represents this relation is "gtin".',
#  'publisher',
#  'category',
#  'The relation between the two columns seems to be "numTracks" as the values in column 2 appear to be the number of tracks or chapters in each of the items listed in column 1.',
#  'The type that best represents the relation between these two columns is `inStock`.',
#  'The relation between the two columns is not clear and there is no apparent connection between them. Therefore, the answer is "no relation".',
#  'availability',
#  'It is not possible to classify the relation between the two columns as they do not seem to have any meaningful connection. Column 1 contains a list of various items such as a poster, a map, trade receipts, and a book title, while Column 2 contains a list of numbers.',
#  'The type of relation between the two columns is publisher.',
#  'The relation between the two columns seems to be "bookTitle".',
#  'It is not clear what the relation is between the two columns. None of the given types seem to fit. Could you please provide more context or information?',
#  'The type of relation between the two columns is itemCondition.',
#  'The relation between the two columns is "genre".',
#  'The relation between the two columns is byISBN.',
#  'itemCondition',
#  'category',
#  'The relation between the two columns is "author".',
#  'category',
#  'category',
#  'category',
#  'category',
#  'The type that best represents the relation between the two columns is "eventDate".',
#  'Based on the values in Column 2, it seems that they represent time durations in minutes. Therefore, the type that best represents the relation between the two columns is `duration`.',
#  "I'm sorry, but I cannot find any relation between the two columns. The first column seems to be a list of events and their status, while the second column seems to indicate the availability of some items. Could you please provide more context or clarify the task?",
#  'The type that best represents the relation between the two columns is "location".',
#  'The type that best represents the relation between the two columns is "eventDate".',
#  'The type that best represents the relation between the two columns is "EventScheduled".',
#  'The type that best represents the relation between the two columns is "event".',
#  'The type that best represents the relation between the two columns is "eventDate".',
#  'category',
#  'The relation between the two columns seems to be "address" as the values in column 2 are all addresses.',
#  'Based on the given values in both columns, it seems that there is no clear relation between them. Therefore, I would classify the type as "N/A" (not applicable).',
#  'category',
#  'It seems that there is no clear relation between the two columns. The values in column 2 are all "inStock" which is related to availability of a product, while the values in column 1 are names of events. Therefore, I cannot classify the relation between these two columns with any of the given types.',
#  'The type that best represents the relation between the two columns is "eventDate".',
#  'The relation between the two columns is "organizer" as the values in column 2 represent the organizer of the events mentioned in column 1.',
#  "There doesn't seem to be any clear relation between the two columns. Column 1 contains event names and descriptions, while Column 2 contains a repeated phone number. Therefore, I cannot classify the relation between these two columns with any of the given types.",
#  'The relation between the two columns is not clear. It seems like the first column contains event names and the second column contains currency values, but there is no clear relation between them. Therefore, I cannot classify the relation between these columns with any of the given types.',
#  'The relation between the two columns is not clear. It seems like Column 1 contains event names or titles, while Column 2 contains the word "primary" repeated multiple times. Without more context or information, it is not possible to classify the relation between these two columns with any of the given types.',
#  'The type of relation between these columns is "eventDate".',
#  'It seems that the values in Column 2 are prices or numerical values associated with some event or activity. Therefore, the type that best represents the relation between the two columns is "price".',
#  'I\'m sorry, but based on the given information, I cannot find a clear relation between the two columns. Column 1 seems to contain event names or titles, while Column 2 contains the status of being "InStock". Please provide more context or information so I can assist you better.',
#  'The type of relation between these columns is "eventDate".',
#  'The type that best represents the relation between the two columns is "EventScheduled".',
#  'The type that best represents the relation between the two columns is eventAttendanceMode. Therefore, the answer is eventAttendanceMode.',
#  'The relation between the two columns seems to be related to the schedule or timing of the events mentioned in Column 1. Therefore, the type that best represents this relation is "schedule" or "timing".',
#  'The type that best represents the relation between the two columns is `eventAttendanceMode`.',
#  'The relation between the two columns seems to be "organizer" as both columns contain names of individuals or projects that are organizing or associated with the events listed in column 1. Therefore, the answer is "organizer".',
#  'The type that best represents the relation between the two columns is `telephone`.',
#  'The relation between the two columns seems to be contact information for events and conferences. Therefore, the type is `email`.',
#  'The type that best represents the relation between the two columns is "organizer".',
#  'The relation between the two columns is address/telephone number. Therefore, the type is "telephone".',
#  'The relation between the columns seems to be the organizer of the events/programs mentioned in column 1. Therefore, the type is "organizer".',
#  'It seems that both columns are not related to each other. The values in column 2 are all the same and do not provide any information about the values in column 1. Therefore, the relation between these columns is not classifiable with the given types.',
#  "I'm sorry, but based on the given columns, I cannot find any relation between them that can be classified with the types provided. The values in Column 2 seem to indicate availability of some items, while the values in Column 1 seem to be a list of events. Could you please provide more context or information?",
#  'The type that best represents the relation between the two columns is "eventDate".',
#  'The relation between the two columns is "event".',
#  'The relation between the two columns seems to be events and their respective organizers. Therefore, the type that best represents this relation is "organizer".',
#  'The type that best represents the relation between the two columns is "County Council Meeting".',
#  'The type that best represents the relation between the two columns is "email".',
#  'The relation between the two columns seems to be "committee member" or "committee participant".',
#  'It seems that the values in Column 2 are phone numbers, which are not related to the values in Column 1. Therefore, the type of relation between these columns is "unrelated".',
#  'The type that best represents the relation between the two columns is "startDate".',
#  'The type that best represents the relation between the two columns is eventAttendanceMode.',
#  'The relation between the two columns is "url".',
#  'The type that best represents the relation between the two columns is "EventScheduled".',
#  'The relation between the two columns is `byArtist`.',
#  'The relation between the two columns is `location`.',
#  'The relation between the two columns is "location" as both columns are indicating the location of the events or opportunities mentioned in column 1.',
#  'The relation between the two columns seems to be "address".',
#  'The type that best represents the relation between the two columns is `postalCode`. The values in column 2 are postal codes, which are related to the events/workshops mentioned in column 1.',
#  'location',
#  'The relation between the two columns seems to be "location".',
#  'The relation between the two columns seems to be "addressRegion".',
#  'The relation between the two columns seems to be "addressLocality" as all the values in column 2 are the locality/city names where the entities in column 1 are located.',
#  'The type that best represents the relation between the two columns is `postalCode`.',
#  'The relation between Column 1 and Column 2 seems to be the address of the businesses mentioned in Column 1. Therefore, the type of relation is "address".',
#  'Based on the given values in the columns, the relation between them seems to be related to contact information. Therefore, the type that best represents the relation between the two columns is `telephone`.',
#  'Based on the given columns, the type that best represents the relation between them is "manufacturer".',
#  'Based on the given columns, it seems that there is no clear relation between them. Column 1 contains a list of company or brand names, while column 2 contains a list of numbers. Therefore, it is not possible to classify the relation between these columns with any of the given types.',
#  'The relation between the two columns seems to be the release date of the movies mentioned in Column 1. Therefore, the type that best represents this relation is "releaseDate".',
#  'Type: actor',
#  'The relation between the two columns seems to be the `totalTime` of the movies listed in column 1. Therefore, the type that best represents the relation between the two columns is `totalTime`.',
#  'The relation between the two columns is byArtist, as the values in column 2 are the movie posters of the movies listed in column 1, and the artist responsible for creating these posters is the same.',
#  'Type: url',
#  'The relation between the two columns seems to be "byArtist" as the second column contains the names of actors who might have acted in the movies or documentaries mentioned in the first column.',
#  'The relation between Column 1 and Column 2 seems to be related to the directors of the movies mentioned in Column 1. Therefore, the type that best represents this relation is "director".',
#  'The type that best represents the relation between the two columns is "image".',
#  'The relation between the two columns is "actor" as the values in column 2 are the actors who starred in the movies listed in column 1.',
#  'The relation between the two columns seems to be the itemCondition, as the values in column 2 represent the rating or classification of the movies in column 1.',
#  'The type that best represents the relation between the two columns is "genre".',
#  'The relation between Column 1 and Column 2 is "director".',
#  'The relation between the two columns is "director" as the values in column 2 represent the directors of the movies listed in column 1.',
#  'The relation between Column 1 and Column 2 seems to be that Column 2 lists the directors of the movies mentioned in Column 1. Therefore, the type that best represents this relation is "director".',
#  'The relation between the two columns is itemCondition, as the second column describes the rating of the movies in the first column.',
#  'The relation between the two columns is "byArtist" as all the songs in Column 1 are performed by the same artist, Bryan Hayes, which is mentioned in Column 2.',
#  'The relation between the two columns is "year" as it represents the year in which each song was performed live. Therefore, the type is "datePublished".',
#  'The type of relation between these columns is `duration`.',
#  'The type that best represents the relation between the two columns is "title".',
#  'The relation between the two columns is byNationality.',
#  'The type that best represents the relation between the two columns is "playerPosition".',
#  'The type that best represents the relation between the two columns is "homeTeam".',
#  'The relation between the two columns is byArtist, as all the values in column 1 are names of chefs and all the values in column 2 describe their roles in the culinary industry.',
#  'The relation between the two columns is byArtist, as all the values in column 1 are names of artists, and the values in column 2 are their respective birth dates.',
#  'The relation between the two columns is "gender". Therefore, the type is "gender".',
#  'The type that best represents the relation between the two columns is "actor".',
#  'The type that best represents the relation between the two columns is "byArtist".',
#  'The relation between the two columns seems to be related to the gender of the individuals mentioned in column 1. Therefore, the type that best represents this relation is "gender".',
#  'The relation between the two columns seems to be irrelevant or unclear. Therefore, I cannot classify it with any of the given types.',
#  'The relation between the two columns seems to be related to professions or services. Therefore, the appropriate type for this relation is "hiringOrganization".',
#  'The relation between the two columns seems to be related to the location of the services provided in column 1. Therefore, the type that best represents this relation is "location".',
#  'The relation between the two columns is byNationality.',
#  'The relation between Column 1 and Column 2 seems to be related to the birth dates of the individuals in Column 1. Therefore, the type that best represents this relation is "birthDate".',
#  'actor',
#  'The relation between the two columns seems to be related to the positions played in a football team. Therefore, the type that best represents this relation is "position" or "playerPosition".',
#  'The relation between the two columns seems to be related to the weight of the individuals mentioned in column 1. Therefore, the type that best represents this relation is "weight".',
#  'The type that best represents the relation between the two columns is gender.',
#  'The type that best represents the relation between the two columns is "gender".',
#  'The relation between Column 1 and Column 2 seems to be byArtist, as the values in Column 2 represent the birth years of the artists listed in Column 1.',
#  'The relation between the two columns is "byArtist" as both columns contain names of individuals and the second column describes their profession or job title.',
#  'The relation between the two columns seems to be "byArtist", as the values in column 1 appear to be names of artists, and the values in column 2 could be their contact phone numbers.',
#  'The type that best represents the relation between the two columns is givenName.',
#  'The relation between the two columns is not clear. There is no apparent connection between the product names and descriptions in Column 1 and the dates and times in Column 2. Therefore, it is not possible to classify the relation between these two columns with any of the given types.',
#  'Based on the values of the two columns, it seems that there is no clear relation between them that can be classified using the given types. Column 1 appears to be a list of various Feng Shui items, while Column 2 contains numerical values that do not seem to correspond to any of the types. Therefore, I cannot classify the relation between these columns using the given types.',
#  "There doesn't seem to be any clear relation between the two columns. The first column contains a list of products related to Feng Shui, while the second column contains dates and times. Therefore, I cannot classify the relation between these columns with any of the given types.",
#  'The relation between the two columns is related to the product description and customer reviews. Therefore, the type is "review".',
#  'itemCondition',
#  'The relation between the two columns is itemWeight.',
#  'I\'m sorry, but I cannot find any clear relation between the two columns. The first column seems to contain a list of fitness equipment and their descriptions, while the second column contains only the number "1.0" repeated four times. Could you please provide more context or clarify the task?',
#  'The type that best represents the relation between the two columns is "productType".',
#  'The relation between Column 1 and Column 2 is "MTG Booster Packs".',
#  'The type that best represents the relation between the two columns is "brand".',
#  'The type of relation between the two columns is "product".',
#  'The relation between the two columns is byProduct.',
#  'The relation between the two columns seems to be related to weight capacity or maximum weight that can be handled by the equipment listed in column 1. Therefore, the type that best represents this relation is "weight capacity" or "maximum weight".',
#  'category',
#  'The given values in column 2 seem to be ratings or reviews for the products listed in column 1. Therefore, the type of relation between these columns is "review".',
#  'Based on the values in the two columns, the type that best represents the relation between them is "productReview".',
#  'category',
#  'The relation between Column 1 and Column 2 is "author".',
#  'The relation between the two columns is `priceCurrency`.',
#  'The relation between Column 1 and Column 2 seems to be "publisher".',
#  'The relation between the two columns is `inStock`, as both columns provide information about the availability of the listed items.',
#  'The relation between the two columns seems to be the `price` of the books. Therefore, the type is `price`.',
#  'category',
#  'It is not clear what the relation is between the two columns based on the given information. The types provided do not seem to match the values in the columns. Please provide more context or information to accurately classify the relation between the two columns.',
#  'Type: ISBN',
#  'The type that best represents the relation between the two columns is "category".',
#  'itemCondition',
#  'itemCondition',
#  'The given columns do not have any clear relation to any of the types provided. It seems like Column 1 contains movie or book titles, while Column 2 contains some numerical values. Therefore, I cannot classify the relation between these columns with any of the given types.',
#  'The relation between the two columns is related to the publication date of the books in Column 1. Therefore, the type that best represents this relation is "releaseDate".',
#  'The relation between the two columns is "byArtist" as the first column lists the names of the books written by the author David Baldacci, which is mentioned in the second column.',
#  'The relation between the two columns seems to be related to the book\'s ISBN numbers. Therefore, the type that best represents this relation is "ISBN".',
#  'The relation between the two columns is "publisher".',
#  'The relation between the two columns is "url".',
#  'The type that best represents the relation between the two columns is "genre".',
#  'The relation between Column 1 and Column 2 is "url" as the values in Column 2 are URLs to access the books mentioned in Column 1.',
#  'The relation between the two columns is `ISBN`.',
#  'The relation between the two columns seems to be the publication year of the books in Column 1. Therefore, the type that best represents this relation is "publicationYear".',
#  'category',
#  'The relation between the two columns seems to be "byAuthor" as the first column contains book titles and the second column contains author names.',
#  'The relation between the two columns seems to be unrelated. Therefore, the type is "N/A" (not applicable).',
#  'The relation between the two columns seems to be "numberOfPages".',
#  'The relation between the two columns is "itemCondition".',
#  'The relation between the two columns is byDate.',
#  'category',
#  'byAuthor',
#  'Based on the values in the two columns, the type that best represents the relation between them is "publisher".',
#  'The relation between the two columns is `ISBN` as the values in column 2 are ISBN numbers of the books mentioned in column 1.',
#  'The relation between Column 1 and Column 2 seems to be "author".',
#  'The relation between the two columns seems to be related to the duration or length of something. Therefore, the type that best represents this relation is "totalTime".',
#  'The type of relation between the two columns is "inAlbum".',
#  'The relation between the two columns seems to be related to the ISBN (International Standard Book Number) of the books. Therefore, the type that best represents this relation is "isbn".',
#  'itemCondition',
#  'itemCondition',
#  'The relation between the two columns is "bookEdition".',
#  'The relation between the two columns seems to be the `price` of the items. Therefore, the type is `price`.',
#  'category',
#  'The type of relation between the two columns is byImage.',
#  'The type that best represents the relation between the two columns is "description".',
#  'The relation between the two columns seems to be related to time. Therefore, the type that best represents this relation is "dateCreated".',
#  'The relation between the two columns is "performer" as both columns contain the name of the performer.',
#  'The relation between the two columns is not clear as there is no apparent connection between the values in Column 1 and Column 2. Therefore, I cannot classify the type of relation between these columns with any of the given types.',
#  'performer',
#  'It seems that the second column contains a name, "Yehudit", which is repeated for all the rows. Therefore, the relation between the two columns is byPerson, specifically the person who made or prepared the dishes listed in the first column is Yehudit.',
#  'It is not possible to determine the relation between the two columns as they are completely unrelated to each other.',
#  'category',
#  'The type that best represents the relation between the two columns is "url".',
#  'recipeInstructions',
#  'The type that best represents the relation between the two columns is "event".',
#  'The type that best represents the relation between the two columns is "location".',
#  'The type that best represents the relation between the two columns is `eventAttendanceMode`.',
#  'The type that best represents the relation between the two columns is "event".',
#  'The type that best represents the relation between the two columns is "url" as all the values in column 2 are URLs related to events mentioned in column 1.',
#  'The type that best represents the relation between the two columns is "address".',
#  'The type that best represents the relation between the two columns is `eventAttendanceMode`.',
#  'The type that best represents the relation between the two columns is `url`.',
#  'The type that best represents the relation between the two columns is "location".',
#  'The relation between the two columns seems to be "performer", as the values in column 2 are names of individuals who may have performed at the events or activities mentioned in column 1.',
#  'The type that best represents the relation between these two columns is "EventScheduled".',
#  'The type that best represents the relation between the two columns is "eventAttendanceMode".',
#  'Based on the given columns, it seems that there is no clear relation between them. Therefore, I would classify the relation as "N/A" or "None".',
#  'It seems that there is no clear relation between the values in Column 1 and Column 2. Therefore, I cannot classify the type of relation between these columns with any of the given types.',
#  'I\'m sorry, but it\'s not clear to me what the relation is between the two columns. The first column seems to contain two different types of training, while the second column contains the word "inStock" repeated four times. Could you please provide more context or information about the columns?',
#  'The relation between Column 1 and Column 2 seems to be related to an event or conference. Therefore, the type that best represents this relation is "eventAttendanceMode".',
#  'The relation between the two columns seems to be unrelated. Therefore, the answer is "unrelated".',
#  'The relation between the two columns is not clear. None of the types provided seem to fit this relation. It is possible that there is no clear relation between these two columns.',
#  "I'm sorry, but based on the given columns and types, I cannot find a suitable type that represents the relation between them. It seems that the columns are not related to each other. Can you please provide more information or context about the columns?",
#  'The type that best represents the relation between these two columns is `event`.',
#  'The type that best represents the relation between these two columns is "eventAttendanceMode".',
#  'The type that best represents the relation between the two columns is `eventAttendanceMode`.',
#  'The type that best represents the relation between the two columns is `EventScheduled`.',
#  'The type that best represents the relation between the two columns is "eventAttendanceMode".',
#  'The type that best represents the relation between the two columns is "eventAttendanceMode".',
#  'The relation between Column 1 and Column 2 seems to be related to an event or a performance. Therefore, the appropriate type for this relation is "event".',
#  'The type of relation between these columns is `inLanguage`.',
#  'The type that best represents the relation between these columns is "eventDate".',
#  'The type of relation between these columns is "eventDate".',
#  'organizer',
#  'duration',
#  'category',
#  'The type of relation between the two columns is "event".',
#  'The type of relation between the two columns is `availability`.',
#  'category',
#  'category',
#  'category',
#  'The type of relation between the two columns is "amenityFeature".',
#  'The type that best represents the relation between these columns is "address".',
#  'The type that best represents the relation between the two columns is "hotelName".',
#  'The type that best represents the relation between the two columns is "location".',
#  'The type that best represents the relation between the two columns is "hotel" as all the values in column 1 are the names of a hotel and the values in column 2 are likely ratings for that hotel.',
#  'The relation between the two columns seems to be "numberOfPages". However, it is important to note that this classification is based on the assumption that the values in Column 1 are actually referring to a hotel name and not a book title or something else entirely. If the assumption is incorrect, a different type may be more appropriate.',
#  'The type that best represents the relation between the two columns is `inLanguage`, as the values in column 2 represent the languages in which the hotel name in column 1 is written.',
#  'The relation between the two columns is "amenityFeature".',
#  'The type of relation between these columns is "address".',
#  'location',
#  'The type that best represents the relation between the two columns is "numberOfPages".',
#  'The relation between the two columns seems to be "ratingValue".',
#  'category',
#  'The relation between the two columns is `telephone`.',
#  'The type that best represents the relation between these two columns is `checkInTime`.',
#  'The relation between the two columns is `checkInTime`.',
#  'The type that best represents the relation between the two columns is `inLanguage`.',
#  'The relation between the two columns is `email`.',
#  'The relation between the two columns seems to be the geographical location of the given places. Therefore, the type that best represents this relation is "latitude, longitude".',
#  'The relation between the two columns seems to be the location of the given properties. Therefore, the type that best represents this relation is "location".',
#  'The relation between the two columns seems to be the "ratingValue" of the accommodations listed in column 1. Therefore, the type is "ratingValue".',
#  'The relation between the two columns seems to be the "numberOfRooms" as all the values in column 2 are "1.0" which could represent the number of rooms in each of the properties listed in column 1. Therefore, the type of relation between these columns is "numberOfRooms".',
#  'The relation between the two columns is "ratingValue".',
#  'Based on the given columns, the relation between them seems to be related to the availability or booking information of the listed accommodations. Therefore, the appropriate type for this relation is "availability".',
#  'The relation between the two columns seems to be the availability of the listed accommodations on specific dates. Therefore, the type that best represents this relation is "availability".',
#  'The relation between the two columns seems to be the "location" of the accommodations. Therefore, the type that best represents this relation is "location".',
#  'The type of relation between these columns is "image".',
#  'The relation between the two columns seems to be the location or latitude of the hotels mentioned in column 1. Therefore, the type that best represents this relation is "latitude".',
#  'The relation between the values in Column 1 and Column 2 seems to be related to the geographical location of the hotels. Therefore, the appropriate type for this relation is "latitude, longitude"',
#  'The type that best represents the relation between the two columns is "itemCondition".',
#  'The relation between the two columns seems to be the amenities and services offered by each hotel. Therefore, the appropriate type for this relation is "amenityFeature".',
#  'The relation between the two columns seems to be the "location" of the hotels and the languages spoken in those locations. Therefore, the type that best represents this relation is "location".',
#  'The relation between the two columns seems to be the `address` type.',
#  'The relation between the two columns seems to be the "ratingValue" of the hotels. Therefore, the type is "ratingValue".',
#  'The type that best represents the relation between the two columns is "amenityFeature".',
#  'The type that best represents the relation between these columns is `address`.',
#  'The type that best represents the relation between these two columns is `addressLocality`, as the values in column 2 seem to be the locality or city where the hotels in column 1 are located.',
#  'The relation between the two columns is "ratingValue".',
#  'The type that best represents the relation between the two columns is "numberOfPages".',
#  'The type that best represents the relation between the two columns is `inLanguage`.',
#  'The type that best represents the relation between these two columns is `checkInTime`.',
#  'The type that best represents the relation between these two columns is `checkInTime`.',
#  'The type that best represents the relation between these two columns is "inLanguage".',
#  'The relation between the two columns is `email`.',
#  'The type that best represents the relation between the two columns is `postalCode`.',
#  'The type of relation between the two columns is "amenityFeature".',
#  'The type that best represents the relation between the two columns is `addressLocality`, as the values in column 2 seem to be the locality where the hotels are located.',
#  'The type that best represents the relation between the two columns is `address`.',
#  'itemCondition',
#  'itemCondition',
#  'The relation between the two columns is "inLanguage".',
#  'The type that best represents the relation between the two columns is "checkInTime".',
#  'The relation between the two columns is "inLanguage".',
#  'The relation between the two columns is `price`.',
#  'The type that best represents the relation between the two columns is `checkInTime`.',
#  'The type that best represents the relation between the two columns is "amenityFeature".',
#  'The relation between the two columns seems to be the check-in time of the hotels listed in column 1. Therefore, the type that best represents this relation is "checkInTime".',
#  'The relation between the two columns seems to be "priceRange".',
#  'The type that best represents the relation between the two columns is `address`.',
#  'The type of relation between these columns is openingHours.',
#  'The relation between the two columns seems to be "byArtist" as all the values in column 1 seem to be names of artists or production companies, and the values in column 2 are images related to their work.',
#  'The relation between the two columns seems to be contact information. Therefore, the type is email.',
#  'The type that best represents the relation between these columns is "openingHours".',
#  'The relation between the two columns seems to be the accepted payment methods at the Atelier Mondial Nomad Design & Lifestyle Hotel. Therefore, the type that best represents this relation is "paymentAccepted".',
#  "I'm sorry, but based on the given information, I cannot determine the relation between the two columns. Column 1 seems to contain a list of items or services, while Column 2 contains a list of dollar signs, which could indicate the price range of the items or services in Column 1. However, there is no clear indication of a specific type of relation between the two columns.",
#  'The type that best represents the relation between these columns is `byArtist`. (Note: This is not the correct type for this data, but it was randomly selected from the list of types provided.)',
#  'The type that best represents the relation between these two columns is "byArtist".',
#  'The type that best represents the relation between the two columns is "byArtist".',
#  'The type that best represents the relation between the two columns is `givenName`, as the values in column 1 appear to be the first names of different doctors, while the values in column 2 are all the same.',
#  'The relation between the two columns is "consultedWith".',
#  'The relation between the two columns is "byArtist" as the values in column 1 are names of doctors and column 2 contains the currency used for their services.',
#  'The type that best represents the relation between these columns is "openingHours".',
#  'It seems that there is no clear relation between the values in the two columns. Therefore, I cannot classify the type of relation between these columns.',
#  'totalTime',
#  'The relation between the two columns is movie rating.',
#  'The type that best represents the relation between the two columns is `productionCompany`.',
#  'The given columns do not have any clear relation between them. Therefore, it is not possible to classify the type of relation between them.',
#  'Based on the values in the two columns, the best type that represents the relation between them is "duration". Therefore, the answer is "duration".',
#  "I'm sorry, but based on the given columns, I cannot determine a clear relation between them. The first column seems to contain a list of names and descriptions, while the second column contains dates. Can you please provide more context or information about the columns?",
#  'category',
#  "I'm sorry, but I cannot find any clear relation between the two columns. It seems like the values in column 1 are a list of words or phrases, while the values in column 2 are a list of names. Can you please provide more context or information about these columns?",
#  'Based on the given columns, the relation between them cannot be determined. None of the types provided seem to fit the given data. It is possible that there is missing information or context that would help determine the relation between the two columns.',
#  'Based on the given columns, it is difficult to determine a clear relation between them. However, if we assume that the numbers in column 2 represent a rating or score given to each item in column 1, then the most appropriate type to classify the relation between the two columns would be "ratingValue".',
#  "I'm sorry, but I cannot classify the relation between the two columns as they do not seem to have any meaningful relationship. Column 1 contains a list of words that do not appear to be related to each other, and column 2 contains a list of 1s. Could you please provide more context or information about the columns?",
#  'totalTime',
#  'The relation between the two columns seems to be a review rating for the movies listed in column 1. Therefore, the type is "review".',
#  'The relation between the two columns is not clear. Column 1 seems to contain movie titles, while column 2 contains the value 1.0 repeated multiple times. Without further context or information, it is not possible to classify the relation between these two columns with any of the given types.',
#  'The relation between the two columns seems to be a review rating for the movies listed in column 1. Therefore, the type is "review".',
#  'inLanguage',
#  'Type: actor',
#  'The type that best represents the relation between the two columns is "inAlbum".',
#  'The relation between the two columns is "productionCompany".',
#  'The relation between the two columns seems to be the release date of the movies mentioned in column 1. Therefore, the type that best represents this relation is "releaseDate".',
#  'director',
#  'The relation between the two columns seems to be "performer".',
#  'Based on the given values in the columns, the relation between them cannot be determined. Therefore, it is not possible to classify the type of relation between these columns.',
#  'It seems that there is no clear relation between the two columns. Therefore, the type of relation is "N/A" or "None".',
#  'Based on the given columns, it seems that Column 1 represents the names of different videos or movies, while Column 2 represents the duration of each video or movie. Therefore, the type that best represents the relation between these two columns is "totalTime".',
#  'The relation between the two columns seems to be "performer". The values in column 2 appear to be the performers or actors associated with the items listed in column 1.',
#  'The relation between the two columns seems to be the performers or cast members associated with each item in Column 1. Therefore, the type that best represents this relation is "performer".',
#  'The relation between the two columns seems to be "totalTime" as the values in column 2 represent the total duration of the events/movies/concerts mentioned in column 1.',
#  'There is no clear relation between the values in Column 1 and Column 2. Therefore, the type of relation between these columns is "N/A" (not applicable).',
#  'Based on the given columns, it seems that the relation between them is related to the movie ratings. Therefore, the type that best represents this relation is "ratingValue".',
#  'The relation between the two columns seems to be that the movies listed in Column 1 have actors listed in Column 2. Therefore, the type that best represents this relation is "actor".',
#  'totalTime',
#  'category',
#  'The relation between the two columns seems to be the content rating of the movies listed in column 1. Therefore, the type that best represents this relation is "contentRating".',
#  'The relation between the two columns seems to be "director" as the values in column 2 are the directors of the TV shows and movies listed in column 1. Therefore, the answer is "director".',
#  'The relation between the two columns is related to the release date of the TV shows and movies mentioned in column 1. Therefore, the type that best represents this relation is "releaseDate".',
#  'The relation between the two columns seems to be "ratingValue" as both columns contain ratings for the listed TV shows.',
#  'The relation between the two columns seems to be "episodeNumber".',
#  'The type that best represents the relation between the two columns is "TV Show Plot Summary".',
#  'The relation between the two columns is "image".',
#  'The relation between the two columns seems to be the "TV Show Seasons" and their respective "Genres". Therefore, the type that best represents this relation is "genre".',
#  'The type that best represents the relation between the two columns is "performer".',
#  'genre',
#  'The relation between Column 1 and Column 2 seems to be "actor" as the values in Column 2 are the names of actors who appeared in the movies listed in Column 1.',
#  'The relation between the two columns seems to be the production company of the movies listed in column 1. Therefore, the type that best represents this relation is "productionCompany".',
#  'The relation between the two columns is totalTime.',
#  'The type that best represents the relation between the two columns is "countryOfOrigin".',
#  'The relation between the two columns is "movieTitle".',
#  'The relation between Column 1 and Column 2 is "director".',
#  'The relation between Column 1 and Column 2 seems to be related to the Total Time (duration) of the movies. Therefore, the type that best represents this relation is "totalTime".',
#  'The relation between the two columns seems to be related to the release date of the movies mentioned in column 1. Therefore, the type that best represents this relation is "releaseDate".',
#  'The relation between the two columns seems to be "byArtist" as the values in column 2 are the names of actors who have acted in the movies listed in column 1.',
#  'The relation between Column 1 and Column 2 seems to be a movie review. Therefore, the type is "review".',
#  'The relation between the two columns seems to be "director" as the values in column 2 are names of directors who directed the movies listed in column 1. Therefore, the answer is "director".',
#  'The relation between the two columns is not clear. It seems like Column 1 contains movie titles and Column 2 contains the country "India" for all the movies. Therefore, the best type to represent the relation between these columns is "countryOfOrigin".',
#  'The relation between Column 1 and Column 2 is byArtist, as each album title in Column 1 is associated with a corresponding image of the album cover in Column 2.',
#  'The relation between the two columns seems to be "numberOfPages". However, this type is not appropriate for this case since the first column contains album titles and the second column contains the number of tracks or songs in each album. Therefore, the appropriate type for this relation is "numTracks".',
#  'It seems that there is no clear relation between the two columns. Therefore, the type of relation between these columns is "N/A" (not applicable).',
#  'The relation between the two columns seems to be the duration of songs in each album. Therefore, the type is "totalTime".',
#  'byArtist',
#  'The relation between the two columns seems to be the duration of the songs in Column 1. Therefore, the type is "totalTime".',
#  'The relation between the two columns seems to be "byArtist" as the values in column 1 are album or song titles and the values in column 2 are the names of the artists who created them.',
#  'byArtist',
#  'The relation between the two columns is byAlbumReleaseDate.',
#  'The given values in column 2 seem to be track numbers of the songs in column 1. Therefore, the type that best represents the relation between these two columns is "track".',
#  'byArtist',
#  'The relation between Column 1 and Column 2 seems to be related to the birthplace of the individuals mentioned in Column 1. Therefore, the type that best represents this relation is "birthPlace".',
#  'The relation between the two columns is byArtist, as all the names in column 1 are racing drivers and the dates in column 2 are their respective birth dates.',
#  'The relation between Column 1 and Column 2 seems to be related to the nationality of the individuals in Column 1. Therefore, the type that best represents this relation is "nationality".',
#  'The relation between the two columns is byArtist, as all the values in column 1 are names of artists and column 2 contains their respective birth years.',
#  'The type that best represents the relation between the two columns is "byArtist".',
#  'The relation between the two columns is byArtist, as all the values in column 2 are the last names of the artists in column 1.',
#  'The type of relation between the two columns is "byArtist".',
#  'The relation between the two columns is "byArtist" as the values in column 2 are the names of the artists or creators in column 1.',
#  'The relation between the two columns seems to be "byArtist" as the values in column 1 appear to be names of artists and column 2 contains surnames of two individuals, which could be the names of the artists\' works or projects.',
#  'The type that best represents the relation between these two columns is "gender". Therefore, the answer is "gender".',
#  'The type that best represents the relation between the two columns is "byArtist", as the values in column 1 are names of artists and the values in column 2 are years that may represent the release dates of their works.',
#  'The relation between the two columns seems to be "byArtist" as the first column contains a list of artists\' names and the second column contains a subset of those names.',
#  'The type that best represents the relation between the two columns is "byArtist". The values in column 2 are the names of artists, and the values in column 1 are likely works of art or performances that these artists have created or participated in. Therefore, the "byArtist" type is the most appropriate.',
#  'The relation between the two columns seems to be related to the birth year of the individuals mentioned in column 1. Therefore, the type that best represents this relation is "birthDate".',
#  'The relation between the two columns seems to be the birthplace of the individuals listed in column 1. Therefore, the type that best represents this relation is "birthPlace".',
#  'The type that best represents the relation between the two columns is "byArtist".',
#  'The relation between the two columns seems to be "byArtist", as the values in column 2 appear to be the names of the artists whose works are listed in column 1.',
#  'The relation between the two columns is "byArtist" as the values in column 1 seem to be names of cyclists and column 2 contains their birth dates.',
#  'The type that best represents the relation between these two columns is `gender`.',
#  'The relation between Column 1 and Column 2 is byCountry.',
#  'The relation between Column 1 and Column 2 seems to be the year of creation of artworks by the artists listed in Column 1. Therefore, the type that best represents this relation is "releaseDate".',
#  'The type that best represents the relation between the two columns is "gender". Therefore, the answer is "gender".',
#  'The relation between the two columns seems to be "byArtist" as the first column lists the names of artists and the second column lists the art schools they attended.',
#  'The relation between the two columns is byArtist, as the values in column 1 are all artists and the values in column 2 represent their places of birth or origin.',
#  'The relation between the two columns is byArtist, as the values in column 1 are names of artists and the values in column 2 are the years of their birth.',
#  'The relation between the two columns seems to be related to the professions or job titles of the individuals mentioned. Therefore, the type that best represents the relation between the two columns is "jobTitle".',
#  'byArtist',
#  'The relation between the two columns seems to be related to the professional titles of the individuals mentioned in Column 1. Therefore, the type that best represents the relation between the two columns is "itemCondition".',
#  'The type that best represents the relation between these two columns is "weight". Therefore, the answer is "weight".',
#  'The relation between Column 1 and Column 2 seems to be "height" as all the values in Column 2 represent the height of the individuals mentioned in Column 1. Therefore, the type is "height".',
# ...
#  'The relation between the two columns is `checkInTime`.',
#  'The relation between the two columns is not clear. It seems like both columns are just repeating the same values without any meaningful connection between them. Therefore, I cannot classify the relation between these columns with any of the given types.',
#  'totalTime',
#  'The relation between the two columns seems to be the release date of the movies mentioned in column 1. Therefore, the type that best represents this relation is "releaseDate".',
#  'The relation between the two columns is itemCondition, as the values in column 2 represent the rating of the movies listed in column 1.',
#  'The relation between the two columns seems to be "director".',
#  'Based on the given columns, it seems that Column 2 represents the ratings or scores of the movies listed in Column 1. Therefore, the type of relation between these columns is "ratingValue".',
#  'Based on the given columns, it seems that there is no clear relation between the values in Column 1 and Column 2. Therefore, I would classify the type of relation as "None".',
#  'The relation between the two columns seems to be "cast" or "actors".',
#  'Based on the values in the two columns, it seems that there is no clear relation between them. Therefore, I would classify the type as "unclear" or "no relation".',
#  'The relation between the two columns is not clear. None of the types provided seem to fit. Could you please provide more context or information about the columns?',
#  'performer',
#  'performer',
#  'The relation between the two columns is performer, as the values in column 1 are the names of scenes and column 2 contains images of the performer Francesca Le.',
#  'The type of relation between these columns is "url".',
#  'The relation between the two columns is "productionCompany".',
#  'The relation between the two columns is "ratingValue".',
#  'The relation between the two columns is not clear. Column 1 seems to be a list of movie titles, while column 2 seems to be a list of ratings. Without more context, it is difficult to determine a type that represents the relation between these columns.',
#  'totalTime',
#  'The type that best represents the relation between the two columns is "releaseDate".',
#  'The relation between the two columns is "itemCondition".',
#  'The relation between the two columns is not clear as the first column contains movie titles and the second column contains the value "10" repeated multiple times. Therefore, it is not possible to classify the relation between these two columns with any of the given types.',
#  'The relation between the two columns seems to be "director" as the values in column 2 are the names of the directors of the movies listed in column 1.',
#  'The relation between the two columns seems to be a review or rating of the movies listed in column 1. Therefore, the type is "review".',
#  'The relation between the two columns is "cast".',
#  'category',
#  'totalTime',
#  'The type that best represents the relation between the two columns is "releaseDate".',
#  'The relation between the two columns is itemCondition, as the second column provides the rating or item condition of the movies listed in the first column.',
#  'The relation between the two columns is "director".',
#  'The type that best represents the relation between the two columns is `numberOfPages`. However, since this type is not applicable to this scenario, another possible type could be `duration`, as all the movies listed in column 1 have a duration of 10.',
#  'The relation between the two columns seems to be the "ratingValue" of the movies. Therefore, the type is "ratingValue".',
#  'The type that best represents the relation between the two columns is `numTracks`.',
#  'The relation between the two columns is "cast".',
#  'The relation between the two columns is byArtist, as the values in column 1 are names of artists and column 2 contains their respective birth dates.',
#  'The type that best represents the relation between the two columns is "byArtist".',
#  'The relation between the two columns seems to be "byArtist", as the values in column 2 are the last names of the artists listed in column 1.',
#  'The type that best represents the relation between the two columns is `byArtist`.',
#  'The relation between the two columns is byArtist, as all the values in column 1 are names of artists or preachers.',
#  'The type that best represents the relation between the two columns is "givenName". All the names in column 1 are given names of individuals, and all the names in column 2 are titles that can be used to address individuals.',
#  'The relation between the two columns is `birthDate`.',
#  'The type that best represents the relation between the two columns is `datePublished`.',
#  'The relation between the two columns seems to be the givenName of a person. Therefore, the type is "givenName".',
#  'The relation between the two columns is byArtist, as all the names in column 1 are artists and the names in column 2 are their last names.',
#  'The type that best represents the relation between these two columns is "gender". Therefore, the answer is "gender".',
#  'The relation between Column 1 and Column 2 is related to the birthdate of the individuals in Column 1. Therefore, the type that best represents this relation is "birthDate".',
#  'The type that best represents the relation between the two columns is "datePublished".',
#  'The type of relation between the two columns is deathDate.',
#  'The relation between the two columns is byBirthDate.',
#  'The type that best represents the relation between the two columns is "byArtist".',
#  'The relation between the two columns seems to be "byArtist", as the values in column 2 appear to be the names of artists, and the values in column 1 seem to be a list of names that include those artists.',
#  'The type that best represents the relation between these two columns is `gender`.',
#  'The relation between Column 1 and Column 2 is byArtist, as the values in Column 1 appear to be names of artists and the values in Column 2 appear to be their birth dates.',
#  'The type that best represents the relation between these two columns is "gender".',
#  'The relation between Column 1 and Column 2 seems to be byArtist, as the values in Column 1 appear to be names of artists, and the values in Column 2 appear to be the countries associated with those artists.',
#  'The type that best represents the relation between the two columns is "byArtist", as the values in column 1 appear to be names of artists, and the values in column 2 appear to be the countries they are associated with.',
#  "There doesn't seem to be any clear relation between the values in the two columns. Therefore, I cannot classify the type of relation between these columns.",
#  'The relation between Column 1 and Column 2 seems to be byArtist, as the values in Column 1 appear to be names of individuals, and the values in Column 2 appear to be countries. It is possible that these individuals are artists or musicians from the respective countries.',
#  'The type that best represents the relation between the two columns is "byArtist", as all the names in column 1 are boxers, and column 2 specifies that they are all boxers.',
#  'The type that best represents the relation between the two columns is "byArtist".',
#  'The type that best represents the relation between these two columns is `gender`.',
#  'The type that best represents the relation between the two columns is "byArtist". The values in column 2 seem to be a subset of the values in column 1, and they all appear to be names of artists. Therefore, it is likely that column 1 contains a list of artists, and column 2 contains a subset of those artists.',
#  'The given columns seem to represent the birthdates of the individuals listed in column 1. Therefore, the type of relation between these columns is "birthDate".',
#  'The relation between Column 1 and Column 2 seems to be related to the profession or job title of the individuals mentioned in Column 1. Therefore, the type that best represents this relation is "profession" or "jobTitle".',
#  'The relation between the two columns seems to be "byArtist", as the values in column 2 appear to be a subset of the values in column 1, and they all seem to be names of artists.',
#  'The type that best represents the relation between the two columns is "byArtist".',
#  'The relation between the two columns is byArtist, as all the names in column 1 are artists/performers.',
#  'The type that best represents the relation between the two columns is `givenName`. The first column contains a list of given names, while the second column contains dates. There is no clear relationship between the two columns, but given that the first column contains names, `givenName` seems like the most appropriate type.',
#  'The type of relation between these columns is "obituary".',
#  'The type that best represents the relation between the two columns is `birthDate`.',
#  'The type that best represents the relation between the two columns is `datePublished`.',
#  'The type of relation between the two columns is "obituary".',
#  'The relation between the two columns seems to be related to the birthdate of the individuals in column 1. Therefore, the type that best represents this relation is "birthDate".',
#  'The type that best represents the relation between the two columns is "datePublished".',
#  'The type of relation between the two columns is deathDate.',
#  'The type that best represents the relation between the two columns is `datePublished`.',
#  'The relation between the two columns is related to birthdates. Therefore, the type that best represents this relation is "birthDate".',
#  'The type that best represents the relation between these two columns is `datePublished`.',
#  'The type that best represents the relation between the two columns is "byArtist".',
#  'The relation between the two columns seems to be the givenName of individuals in Column 1 and their corresponding middle names in Column 2. Therefore, the type of relation between these columns is "givenName".',
#  'The type that best represents the relation between the two columns is givenName, as the first column contains a list of given names and the second column contains dates that are not related to any other type.',
#  'The relation between the two columns is byDate.',
#  'The type that best represents the relation between the two columns is "byArtist".',
#  'The type that best represents the relation between the two columns is `gender`.',
#  'The type that best represents the relation between the two columns is "byArtist". The values in column 2 are all last names of artists that appear in column 1.',
#  'The relation between the two columns seems to be related to dates of birth. Therefore, the type that best represents this relation is "birthDate".',
#  'The relation between the two columns seems to be the countries associated with the names in Column 1. Therefore, the type that best represents this relation is "countryOfOrigin".',
#  'The relation between the two columns is byArtist, as the values in column 1 appear to be names of artists or performers, and the values in column 2 appear to be their birth dates.',
#  'The type that best represents the relation between the two columns is "byArtist".',
#  'The type that best represents the relation between the two columns is "byArtist".',
#  'The relation between the two columns seems to be the nationality/country of origin of the individuals listed in Column 1. Therefore, the type that best represents this relation is "nationality" or "countryOfOrigin".',
#  'The relation between the two columns is "height" or "heightMeasurement". Therefore, the type is "unitCode".',
#  'The relation between the two columns is "byArtist" as the first column contains a list of artists\' names and the second column contains the countries they belong to.',
#  'The type that best represents the relation between the two columns is "byArtist".',
#  'The relation between the two columns seems to be the `location` where these individuals have played football.',
#  'The type that best represents the relation between the two columns is "height" or "heightMeasurement".',
#  'The relation between Column 1 and Column 2 seems to be byCountry, as each name in Column 1 is associated with a country in Column 2. Therefore, the type is byCountry.',
#  'It seems that the two columns represent a list of names and a list of cities. Therefore, the type that best represents the relation between these two columns is "location".',
#  'The type that best represents the relation between these two columns is givenName, as the first column contains a list of given names and the second column contains their corresponding birth dates and ages.',
#  'The relation between Column 1 and Column 2 is not clear. None of the given types seem to fit this relation. It is possible that there is missing information or context that could help determine the appropriate type.',
#  'The relation between Column 1 and Column 2 is related to "BOC Category D Continuing Education for Athletic Trainers".',
#  'The relation between the two columns is "itemCondition".',
#  'The type that best represents the relation between the two columns is "itemCondition".',
#  'The relation between the two columns seems to be related to the weight of the products being sold in bulk. Therefore, the type that best represents this relation is "weight".',
#  'The relation between the two columns is based on the weight of the items. Therefore, the type is "weight".',
#  'The relation between the two columns is not clear and cannot be classified with any of the given types.',
#  'The type that best represents the relation between the two columns is datePublished.',
#  'I\'m sorry, but based on the information you provided, I cannot determine the relation between the two columns. Column 1 seems to contain a list of different products, while Column 2 only contains the letters "KGM" repeated multiple times. Could you please provide more context or information?',
#  'The type that best represents the relation between the two columns is "itemCondition" as it describes the condition of the items being sold. However, since the column 2 values are timestamps, it is not possible to determine the item condition from this information alone. Therefore, the relation between the two columns cannot be accurately classified with the given information.',
#  'The relation between the two columns is itemCondition, as both columns are describing the condition of the items listed in column 1, which is "Organic T-Shirt" and "Vintage Cotton Twill Cap - Asengana Steampunk Mug", and the condition is "KGM" for all items.',
#  'There doesn\'t seem to be a clear relation between the two columns. Column 1 contains product names and descriptions, while Column 2 contains weight measurements. Therefore, I would classify the relation between these columns as "N/A" or "None".',
#  "There doesn't seem to be a clear relation between the two columns. However, if I had to choose a type, I would say `gtin` as it appears that the values in column 2 could be Global Trade Item Numbers (GTINs) which are used to identify products.",
#  'There doesn\'t seem to be a clear relation between the two columns. However, based on the values in Column 2, it seems like they could be product IDs or GTINs (Global Trade Item Numbers). Therefore, the type of relation between the two columns is "gtin".',
#  'The relation between the two columns seems to be related to the price of the products mentioned in column 1. Therefore, the type of relation is "price".',
#  'The relation between the two columns seems to be related to the weight of the products mentioned in column 1. Therefore, the type that best represents this relation is "weight".',
#  'category',
#  'The relation between the two columns seems to be the amount of grams of some nutritional values in the dishes mentioned in Column 1. Therefore, the type that best represents this relation is "nutrition".',
#  ...]
